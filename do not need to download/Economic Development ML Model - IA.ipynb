# %%
### Economic Development Capstone

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import hashlib
from sklearn.model_selection import train_test_split
import scipy.stats as stats
import statistics

# %matplotlib inline

pd.options.display.float_format = '{:.2f}'.format #Stop displaying scientific notation

# %% [markdown]
# ### Load Data:

# %%
df_suc = pd.read_csv("edp_closed.csv") #Closed projects
df_can = pd.read_csv("edp_cancelled.csv") #Cancelled projects
df_wip = pd.read_csv("edp_under_contract.csv") #Projects in progress

# %% [markdown]
# ### Rename Columns

# %%
#Successful Projects
df_suc.rename({'Company Name': 'company_name', 'County': 'county', 'City':'city', 'Status': 'status', 'Program':'program', 'Primary Funding Agreement':'primary_funding',
              'Award Date':'award_date', 'Total Project Cost':'total_project_cost', 'Capital Investment':'company_funding',
              'Direct Assistance Awarded':'direct_assistance_awarded','Tax Benefits Awarded':'tax_benefits_awarded',
              'Projected Jobs - Created':'projected_jobs_created', 'Projected Jobs - Retained':'projected_jobs_retained', 'Projected Jobs - Other': 'p_jobs_other', 'Projected Jobs - Total': 'p_jobs_total',
              'Projected Qualifying Wage': 'p_qualwage', 'Contracted Jobs - Created':'cont_jobs_created',
              'Contracted Jobs - Retained':'cont_jobs_retained', 'Contracted Jobs - Other Created':'cont_jobs_othercreated',
              'Contracted Jobs - Total':'cont_jobs_total', 'Contracted Qualifying Wage':'cont_qualwage',
              'Verified Total Project Cost':'verified_total_project_cost', 'Project Completion Date':'project_completion_date',
              'Final Jobs - Created':'final_jobs_created', 'Final Jobs - Retained':'final_jobs_retained',
              'Final Jobs - Other Created':'final_jobs_other_created', 'Final Jobs - Total':'final_jobs_total',
              'Project Maintenance Date':'project_maintenance_date', 'City Coordinates':'city_coordinates'}, axis=1, inplace=True)

# %%
#Cancelled/Failured Projects
df_can.rename({'Company Name': 'company_name', 'County': 'county', 'City':'city', 'Status': 'status', 'Program':'program', 'Primary Funding Agreement':'primary_funding',
              'Award Date':'award_date', 'Total Project Cost':'total_project_cost', 'Capital Investment':'company_funding',
              'Direct Assistance Awarded':'direct_assistance_awarded','Tax Benefits Awarded':'tax_benefits_awarded',
              'Projected Jobs - Created':'projected_jobs_created', 'Projected Jobs - Retained':'projected_jobs_retained', 'Projected Jobs - Other': 'p_jobs_other', 'Projected Jobs - Total': 'p_jobs_total',
              'Projected Qualifying Wage': 'p_qualwage', 'Contracted Jobs - Created':'cont_jobs_created',
              'Contracted Jobs - Retained':'cont_jobs_retained', 'Contracted Jobs - Other Created':'cont_jobs_othercreated',
              'Contracted Jobs - Total':'cont_jobs_total', 'Contracted Qualifying Wage':'cont_qualwage',
              #'Verified Total Project Cost':'verified_total_project_cost', 'Project Completion Date':'project_completion_date',
              #'Final Jobs - Created':'final_jobs_created', 'Final Jobs - Retained':'final_jobs_retained',
              #'Final Jobs - Other Created':'final_jobs_other_created', 'Final Jobs - Total':'final_jobs_total',
              #'Project Maintenance Date':'project_maintenance_date',
            'City Coordinates':'city_coordinates'}, axis=1, inplace=True)

# %%
#In-Progress Projects
#Note contacted qualifying wage instead of contracted
df_wip.rename({'Company Name': 'company_name', 'County': 'county', 'City':'city', 'Status': 'status', 'Program':'program', 'Primary Funding Agreement':'primary_funding',
              'Award Date':'award_date', 'Total Project Cost':'total_project_cost', 'Capital Investment':'company_funding',
              'Direct Assistance Awarded':'direct_assistance_awarded','Tax Benefits Awarded':'tax_benefits_awarded',
              'Projected Jobs - Created':'projected_jobs_created', 'Projected Jobs - Retained':'projected_jobs_retained', 'Projected Jobs - Other': 'p_jobs_other',
              'Projected Jobs - Total': 'p_jobs_total',
              'Projected Qualifying Wage': 'p_qualwage', 'Contracted Jobs - Created':'cont_jobs_created',
              'Contracted Jobs - Retained':'cont_jobs_retained', 'Contracted Jobs - Other Created':'cont_jobs_othercreated',
              'Contracted Jobs - Total':'cont_jobs_total', 'Contacted Qualifying Wage':'cont_qualwage',
              'Verified Total Project Cost':'verified_total_project_cost', 'Project Completion Date':'project_completion_date',
              'Final Jobs - Created':'final_jobs_created', 'Final Jobs - Retained':'final_jobs_retained',
              'Final Jobs - Other Created':'final_jobs_other_created', 'Final Jobs - Total':'final_jobs_total',
              'Project Maintenance Date':'project_maintenance_date', 'City Coordinates':'city_coordinates',
              'Date Reported':'date_reported',
              'Project Completion Jobs - Created':'end_of_project_completion_jobs_created',
                'Project Completion Jobs - Retained':'end_of_project_completion_jobs_retained',
                'Project Completion Jobs - Other Created':'end_of_project_completion_jobs_others_created',
                'Project Completion Jobs - Total':'end_of_project_completion_jobs_total',
                'Reported Jobs - Created':'reported_jobs_created',
                'Reported Jobs - Retained':'reported_jobs_retained',
                'Reported Jobs - Other Created':'reported_jobs_others_created',
                'Reported Jobs - Total':'reported_jobs_total',}, axis=1, inplace=True)
#print(df_wip.columns)

# %%
# Adding new columns
df_suc['project_type'] = '2' #Success = 2
df_can['project_type'] = '0' #Cancelled = 0
df_wip['project_type'] = '1' #WIP = 1

# %%
#Create our df by merging the 3 together
df = pd.concat([df_suc, df_can, df_wip]).copy() #Merge the 3 dataframes together

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#                                         company_name       county  \
# 0  DHI Group Inc. (f/k/a Dice Career Solutions, I...         Polk
# 1                        Wacker Chemical Corporation       Monroe
# 2       Environmental Lubricants Manufacturing, Inc.       Grundy
# 3                               McKesson Corporation  Cerro Gordo
# 4                    Peregrine Financial Group, Inc.   Black Hawk
#
#             city                         status  \
# 0      Urbandale  Closed Contracts - Successful
# 1      Eddyville  Closed Contracts - Successful
# 2  Grundy Center        Closed Contracts - Full
# 3     Clear Lake  Closed Contracts - Successful
# 4    Cedar Falls                     Bankruptcy
#
#                                  program primary_funding  award_date  \
# 0                         130% Component      11-130-015  11/18/2010
# 1                         130% Component      12-130-012  11/18/2011
# 2      Value-Added Agriculture Component     11-VAAC-013  05/19/2011
# 3              High Quality Jobs Program    15-HQJDF-034  02/20/2015
# 4  Community Economic Betterment Account     07-CEBA-044  06/13/2007
#
#    total_project_cost  company_funding  direct_assistance_awarded  \
# 0             1750000          1750000                     225000
# 1             7706860          7706860                     150000
# 2              415000           415000                      60000
# 3            65242000         65242000                     170000
# 4            13030000         11650000                     350000
#
#    tax_benefits_awarded  projected_jobs_created  projected_jobs_retained  \
# 0                     0                      16                      154
# 1                344047                       3                       13
# 2                     0                       0                        0
# 3               4200000                     164                        0
# 4                893063                      41                        0
#
#    p_jobs_other  p_jobs_total  p_qualwage  cont_jobs_created  \
# 0             0           170       23.20                 16
# 1             0            16       21.36                  3
# 2             0             0        0.00                  0
# 3             0           164       14.79                164
# 4            12            53       21.38                  0
#
#    cont_jobs_retained  cont_jobs_othercreated  cont_jobs_total  cont_qualwage  \
# 0                  90                       0              106          23.20
# 1                  13                       0               16          21.36
# 2                   0                       0                0           0.00
# 3                   0                       0              164          14.79
# 4                   1                      89               90          21.38
#
#    verified_total_project_cost project_completion_date  final_jobs_created  \
# 0                   5127664.00              11/30/2013               16.00
# 1                   7746970.00              11/30/2014                3.00
# 2                         0.00              06/30/2017                0.00
# 3                  70955084.00              02/28/2018              164.00
# 4                         0.00              06/30/2010                0.00
#
#    final_jobs_retained  final_jobs_other_created  final_jobs_total  \
# 0                90.00                      0.00            106.00
# 1                13.00                      0.00             16.00
# 2                 0.00                      0.00              0.00
# 3                 0.00                      0.00            164.00
# 4                 0.00                      0.00              0.00
#
#   project_maintenance_date              city_coordinates project_type  \
# 0               11/30/2015  POINT (-93.736522 41.630343)            2
# 1               11/30/2016  POINT (-92.630188 41.158178)            2
# 2               06/30/2019  POINT (-92.768301 42.361475)            2
# 3               02/28/2020  POINT (-93.378746 43.137357)            2
# 4               06/30/2012    POINT (-92.4534 42.537809)            2
#
#    end_of_project_completion_jobs_created  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    end_of_project_completion_jobs_retained  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    end_of_project_completion_jobs_others_created  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    end_of_project_completion_jobs_total  reported_jobs_created  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
#
#    reported_jobs_retained  reported_jobs_others_created  reported_jobs_total  \
# 0                     NaN                           NaN                  NaN
# 1                     NaN                           NaN                  NaN
# 2                     NaN                           NaN                  NaN
# 3                     NaN                           NaN                  NaN
# 4                     NaN                           NaN                  NaN
#
#   date_reported
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
#Drop columns we don't need
df.drop(columns=['company_name', 'county', 'city', 'verified_total_project_cost', 'project_completion_date', 'final_jobs_created',
                 'final_jobs_retained', 'final_jobs_other_created', 'final_jobs_total',
                 'project_maintenance_date', 'end_of_project_completion_jobs_created',
                 'end_of_project_completion_jobs_retained', 'primary_funding',
                'end_of_project_completion_jobs_others_created',
                'end_of_project_completion_jobs_total', 'reported_jobs_created',
                'reported_jobs_retained', 'reported_jobs_others_created',
                'date_reported', 'status', 'award_date', 'project_completion_date', 'city_coordinates',
                'projected_jobs_created', 'projected_jobs_retained', 'p_jobs_total', 'p_jobs_other', 'p_qualwage',
                'cont_jobs_created', 'cont_jobs_retained', 'cont_jobs_othercreated', 'cont_qualwage', 'reported_jobs_total'], inplace=True)

# %% [raw]
# #Drop columns we don't need
# df.drop(columns=['company_name', 'primary_funding', 'city', 'project_completion_date', 'project_maintenance_date',
#                  'date_reported', 'status', 'award_date', 'project_completion_date', 'city_coordinates', 'reported_jobs_retained',
#                 'reported_jobs_created', 'verified_total_project_cost', 'final_jobs_created', 'final_jobs_retained',
#                 'final_jobs_other_created', 'final_jobs_total', 'end_of_project_completion_jobs_created',
#                 'end_of_project_completion_jobs_retained', 'end_of_project_completion_jobs_others_created',
#                 'end_of_project_completion_jobs_total', 'reported_jobs_others_created', 'reported_jobs_total'], inplace=True)

# %%
df
# Out:
#                                    program  total_project_cost  \
# 0                           130% Component             1750000
# 1                           130% Component             7706860
# 2        Value-Added Agriculture Component              415000
# 3                High Quality Jobs Program            65242000
# 4    Community Economic Betterment Account            13030000
# ..                                     ...                 ...
# 255              High Quality Jobs Program             8160257
# 256              High Quality Jobs Program             4675000
# 257              High Quality Jobs Program             3546000
# 258              High Quality Jobs Program            60000000
# 259              High Quality Jobs Program          1126218400
#
#      company_funding  direct_assistance_awarded  tax_benefits_awarded  \
# 0            1750000                     225000                     0
# 1            7706860                     150000                344047
# 2             415000                      60000                     0
# 3           65242000                     170000               4200000
# 4           11650000                     350000                893063
# ..               ...                        ...                   ...
# 255          1877621                          0                987132
# 256          4675000                     176000                323000
# 257          3546000                     500000                214800
# 258         48950000                          0               3495000
# 259       1126218400                          0              20256000
#
#      cont_jobs_total project_type
# 0                106            2
# 1                 16            2
# 2                  0            2
# 3                164            2
# 4                 90            2
# ..               ...          ...
# 255               17            1
# 256               64            1
# 257              312            1
# 258              263            1
# 259               84            1
#
# [619 rows x 7 columns]

# %%
df_ct = pd.read_csv("ct_data.csv")

# %%
#Rename columns
df_ct.rename({'Fiscal Year': 'fiscal_year', 'Company Name': 'company_name', 'Company Address':'company_address',
               'Municipality': 'municipality', 'County 1':'county', 'State':'state',
              'Zip Code':'zip_code', 'Business Industry':'company_industry', 'NAICS Code':'naics_code',
              'Minority/ Woman/ Veteran/ International Export':'min_wom_vet_int','Contract Execution Date':'contract_execution_date',
              'Grant Amount':'grant_amount', 'Loan Amount':'loan_amount',
              'Total Project Cost': 'total_project_cost','Amount Leveraged':'company_funding',
              'Funding Source':'program', 'Statutory Reference':'stat_ref',
              'Per Contract: Full-Time CT Jobs to be Retained':'p_ft_job_retention',
              'Per Contract: Full-Time CT Jobs to be Created':'p_ft_job_creation',
              'Per Contract: Part-Time CT Jobs to be Retained':'p_pt_job_retention',
              'Per Contract: Part-Time CT Jobs to be Created':'p_pt_job_creation',
              'Actual Jobs at Time of Review':'actual_jobs', 'Job Obligation Status':'job_obligation_status',
              'Penalty (if applicable)':'penalty', 'Forgiveness Earned (if applicable)':'forgiveness',
              'Per Application: Existing Full-Time Jobs in CT':'existing_ft_jobs',
              'Per Application: Full-Time Jobs to be Created in CT':'original_ft_job_creation',
              'Per Application: Existing Part-Time Jobs in CT':'existing_pt_jobs',
              'Per Application: Part Time Jobs to be Created in CT':'original_pt_job_creation',
              'Full-Time CT Employment at 6/30/20':'full_time_630',
              'Part-Time CT Employment at 6/30/20':'part_time_630',
              'Status':'status', 'Location 1':'location1', 'Count':'count',
              'Geocoded Location':'geo_location', 'Planning Regions':'planning_region',
              'Counties':'counties', 'Zip Code 2':'zipcode2', 'Town Index':'town_index',
              'Total Assistance ':'tot_assistance'
              }, axis=1, inplace=True)

# %%
df_ct
# Out:
#       fiscal_year                                   company_name  \
# 0            2012                  Suffield Village Dental, P.C.
# 1            2013                Berkshire Concrete Cutting, LLC
# 2            2013             Maritime Motors of Fairfield, Inc.
# 3            2014                    Green Power Solutions, Inc.
# 4            2016                           Adam Equipment, Inc.
# ...           ...                                            ...
# 2181         2012                              P.S.I. Plus, Inc.
# 2182         2015  Concentric Tool & Manufacturing Company, Inc.
# 2183         2016                  U.S. Glass Distributors, Inc.
# 2184         2019                  Pieszak-Miller & Brodeur, LLC
# 2185         2015                   Astor Dental Laboratory, LLC
#
#                         company_address  municipality      county state  \
# 0                  215 Suffield Village      Suffield    Hartford    CT
# 1                     3595 Winston Road    Torrington  Litchfield    CT
# 2                          P.O. Box 118         Weare         NaN    NH
# 3                          P.O. Box 501     Woodstock     Windham    CT
# 4                     1 Fox Hollow Road       Danbury   Fairfield    CT
# ...                                 ...           ...         ...   ...
# 2181                      10 Bevin Road  East Hampton   Middlesex    CT
# 2182                  550 Spring Street     Naugatuck   New Haven    CT
# 2183                     7 Niblick Road       Enfield    Hartford    CT
# 2184  100 Essex Street 2E, P.O. Box 173   West Mystic  New London    CT
# 2185     369 New Britain Road, Suite 9A        Berlin    Hartford    CT
#
#       zip_code                                   company_industry naics_code  \
# 0      6078.00                                            Service     621210
# 1      6790.00  Poured Concrete Foundation & Structure Contrac...     238110
# 2      3281.00                                    New Car Dealers     441110
# 3      6281.00                                          Cleantech     238220
# 4      6810.00                             Direct Sells Marketing     454390
# ...        ...                                                ...        ...
# 2181   6424.00                                      Manufacturing     332110
# 2182   6770.00                                       Machine Shop     332710
# 2183   6082.00                 Glass Manufacturer and Distributor     423120
# 2184   6388.00                                           Law Firm     541110
# 2185   6037.00                                  Dental Laboratory     339116
#
#      min_wom_vet_int contract_execution_date  grant_amount  loan_amount  \
# 0                 No              05/17/2012      25238.00         0.00
# 1                 No              09/24/2012     100000.00         0.00
# 2                 No              08/01/2012     100000.00         0.00
# 3                 No              12/23/2013          0.00    100000.00
# 4                 No              11/10/2015     100000.00    300000.00
# ...              ...                     ...           ...          ...
# 2181              No              06/26/2012     100000.00         0.00
# 2182              No              11/06/2014     100000.00         0.00
# 2183       Yes Woman              02/18/2016          0.00    300000.00
# 2184       Yes Woman              06/04/2019     100000.00    300000.00
# 2185              No              10/03/2014      50000.00     68000.00
#
#       tot_assistance  total_project_cost  company_funding  \
# 0           25238.00            50476.00         25238.00
# 1          100000.00           200000.00        100000.00
# 2          100000.00           533000.00        433000.00
# 3          100000.00           100000.00             0.00
# 4          400000.00          2931476.00       2531476.00
# ...              ...                 ...              ...
# 2181       100000.00           201000.00        101000.00
# 2182       100000.00           200000.00        100000.00
# 2183       300000.00           500825.00        200825.00
# 2184       400000.00           500919.00        100919.00
# 2185       118000.00           186000.00         68000.00
#
#                              program        stat_ref p_ft_job_retention  \
# 0     Small Business Express Program  CGS Sec. 32-7g                  0
# 1     Small Business Express Program  CGS Sec. 32-7g                  2
# 2     Small Business Express Program  CGS Sec. 32-7g                 46
# 3     Small Business Express Program  CGS Sec. 32-7g                  1
# 4     Small Business Express Program  CGS Sec. 32-7g                 17
# ...                              ...             ...                ...
# 2181  Small Business Express Program  CGS Sec. 32-7g                  7
# 2182  Small Business Express Program  CGS Sec. 32-7g                 18
# 2183  Small Business Express Program  CGS Sec. 32-7g                 32
# 2184  Small Business Express Program  CGS Sec. 32-7g                  7
# 2185  Small Business Express Program  CGS Sec. 32-7g                  0
#
#      p_ft_job_creation p_pt_job_retention p_pt_job_creation actual_jobs  \
# 0                    1                  0                 0           9
# 1                    0                  0                 0          10
# 2                    2                  0                 0          50
# 3                    5                  0                 0           0
# 4                    5                  0                 0          22
# ...                ...                ...               ...         ...
# 2181                 0                  0                 0           6
# 2182                 3                  0                 0          14
# 2183                 3                  0                 0     Pending
# 2184                10                  0                 0     Pending
# 2185                 2                  0                 0           2
#
#      job_obligation_status        penalty forgiveness existing_ft_jobs  \
# 0                      Met            NaN         NaN                7
# 1                      Met            NaN         NaN                2
# 2                      Met            NaN         NaN               46
# 3                  Not Met  from 2% to 3%         NaN                1
# 4                      Met            NaN         NaN               17
# ...                    ...            ...         ...              ...
# 2181               Not Met         $1,000         NaN                7
# 2182               Not Met  $   33,334.00         OOB               18
# 2183               Pending            NaN         NaN               32
# 2184               Pending            NaN         NaN                7
# 2185                   Met            NaN         NaN                1
#
#      original_ft_job_creation existing_pt_jobs original_pt_job_creation  \
# 0                           1                0                        0
# 1                           0                0                        0
# 2                           2                0                        0
# 3                          11                0                        0
# 4                           6                0                        0
# ...                       ...              ...                      ...
# 2181                        0                0                        0
# 2182                        3                0                        0
# 2183                        3                0                        0
# 2184                       10                0                        0
# 2185                        4                0                        0
#
#      full_time_630  part_time_630                      status  \
# 0              NaN            NaN                      Active
# 1              NaN            NaN                      Active
# 2              NaN            NaN                      Active
# 3              NaN            NaN                      Active
# 4              NaN            NaN                      Active
# ...            ...            ...                         ...
# 2181           NaN            NaN                      Active
# 2182           NaN            NaN  Out of Business- confirmed
# 2183           NaN            NaN                      Active
# 2184             4           1.00                      Active
# 2185           NaN            NaN                      Active
#
#                               location1  count  \
# 0                  215 Suffield Village      1
# 1                     3595 Winston Road      1
# 2                          P.O. Box 118      1
# 3                          P.O. Box 501      1
# 4                     1 Fox Hollow Road      1
# ...                                 ...    ...
# 2181                      10 Bevin Road      1
# 2182                  550 Spring Street      1
# 2183                     7 Niblick Road      1
# 2184  100 Essex Street 2E, P.O. Box 173      1
# 2185     369 New Britain Road, Suite 9A      1
#
#                                            geo_location  planning_region  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4     1 Fox Hollow Road\r\nDanbury, CT 06810\r\n(41....             9.00
# ...                                                 ...              ...
# 2181  10 Bevin Road\r\nEast Hampton, CT 06424\r\n(41...             3.00
# 2182  550 Spring Street\r\nNaugatuck, CT 06770\r\n(4...             4.00
# 2183  7 Niblick Road\r\nEnfield, CT 06082\r\n(41.978...             1.00
# 2184  100 Essex Street 2E, P.O. Box 173\r\nWest Myst...             8.00
# 2185  369 New Britain Road, Suite 9A\r\nBerlin, CT 0...             1.00
#
#       counties  zipcode2  town_index
# 0          NaN       NaN         NaN
# 1          NaN       NaN         NaN
# 2          NaN       NaN         NaN
# 3          NaN       NaN         NaN
# 4      1040.00     45.00       91.00
# ...        ...       ...         ...
# 2181   1043.00    273.00       42.00
# 2182   1044.00    169.00       88.00
# 2183   1041.00    108.00       49.00
# 2184   1045.00    135.00       59.00
# 2185   1041.00    253.00        7.00
#
# [2186 rows x 40 columns]

# %%
#We have a few rows with this See EXP column. Need to remove those.

#TODO: Clean this up so that it's not brute-force.
df_ct = df_ct[df_ct['p_ft_job_creation'].str.contains("See EXP")==False]
df_ct = df_ct[df_ct['p_ft_job_creation'].str.contains("-")==False]
df_ct = df_ct[df_ct['p_ft_job_retention'].str.contains("See EXP")==False]
df_ct = df_ct[df_ct['p_pt_job_retention'].str.contains("-")==False]
df_ct = df_ct[df_ct['p_ft_job_creation'].str.contains("1,385")==False]
df_ct = df_ct[df_ct['p_ft_job_creation'].str.contains("1,385")==False]
df_ct = df_ct[df_ct['p_ft_job_retention'].str.contains("1,385")==False]
df_ct = df_ct[df_ct['p_pt_job_retention'].str.contains("1,385")==False]
df_ct = df_ct[df_ct['original_ft_job_creation'].str.contains("1,900")==False]
df_ct = df_ct[df_ct['original_pt_job_creation'].str.contains("1,900")==False]
df_ct = df_ct[df_ct['original_ft_job_creation'].str.contains("1,900")==False]
df_ct = df_ct[df_ct['original_pt_job_creation'].str.contains("1,900")==False]
df_ct = df_ct[df_ct['original_ft_job_creation'].str.contains("`0")==False]
df_ct = df_ct[df_ct['original_pt_job_creation'].str.contains("`0")==False]
df_ct = df_ct[df_ct['original_ft_job_creation'].str.contains("`0")==False]
df_ct = df_ct[df_ct['original_pt_job_creation'].str.contains("`0")==False]

# %%
df_ct =  df_ct[(df_ct.iloc[:, 1:] != '-').all(axis=1)]

# %%
df_ct['cont_jobs_total'] = df_ct['p_ft_job_creation'].astype(float) + df_ct['p_pt_job_creation'].astype(float)  + df_ct['p_ft_job_retention'].astype(float) + df_ct['p_pt_job_retention'].astype(float)
df_ct['p_jobs_total'] = df_ct['original_ft_job_creation'].astype(float) + df_ct['original_pt_job_creation'].astype(float)

# %% [raw]
# program	total_project_cost	company_funding	direct_assistance_awarded	tax_benefits_awarded	p_jobs_total	cont_jobs_total	project_type

# %%
df_ct.drop(columns=['p_jobs_total', 'fiscal_year', 'company_name', 'company_address', 'municipality', 'county', 'state',
                'zip_code', 'company_industry', 'naics_code', 'min_wom_vet_int', 'contract_execution_date',
                'stat_ref', 'p_ft_job_retention', 'p_ft_job_creation', 'actual_jobs', 'job_obligation_status',
                'penalty', 'forgiveness', 'existing_ft_jobs', 'original_ft_job_creation', 'existing_pt_jobs',
                'original_pt_job_creation', 'full_time_630', 'part_time_630', 'location1',
                'count', 'geo_location', 'planning_region', 'counties', 'zipcode2', 'town_index', 'p_pt_job_retention','p_pt_job_creation'], inplace=True)

# %%
df_ct.rename({'tot_assistance':'direct_assistance_awarded', 'status':'project_type'}, axis=1, inplace=True)
df_ct['tax_benefits_awarded'] = 0

# %%
df_ct
# Out:
#       grant_amount  loan_amount  direct_assistance_awarded  \
# 0         25238.00         0.00                   25238.00
# 1        100000.00         0.00                  100000.00
# 2        100000.00         0.00                  100000.00
# 3             0.00    100000.00                  100000.00
# 4        100000.00    300000.00                  400000.00
# ...            ...          ...                        ...
# 2181     100000.00         0.00                  100000.00
# 2182     100000.00         0.00                  100000.00
# 2183          0.00    300000.00                  300000.00
# 2184     100000.00    300000.00                  400000.00
# 2185      50000.00     68000.00                  118000.00
#
#       total_project_cost  company_funding                         program  \
# 0               50476.00         25238.00  Small Business Express Program
# 1              200000.00        100000.00  Small Business Express Program
# 2              533000.00        433000.00  Small Business Express Program
# 3              100000.00             0.00  Small Business Express Program
# 4             2931476.00       2531476.00  Small Business Express Program
# ...                  ...              ...                             ...
# 2181           201000.00        101000.00  Small Business Express Program
# 2182           200000.00        100000.00  Small Business Express Program
# 2183           500825.00        200825.00  Small Business Express Program
# 2184           500919.00        100919.00  Small Business Express Program
# 2185           186000.00         68000.00  Small Business Express Program
#
#                     project_type  cont_jobs_total  tax_benefits_awarded
# 0                         Active             1.00                     0
# 1                         Active             2.00                     0
# 2                         Active            48.00                     0
# 3                         Active             6.00                     0
# 4                         Active            22.00                     0
# ...                          ...              ...                   ...
# 2181                      Active             7.00                     0
# 2182  Out of Business- confirmed            21.00                     0
# 2183                      Active            35.00                     0
# 2184                      Active            17.00                     0
# 2185                      Active             2.00                     0
#
# [1976 rows x 9 columns]

# %%
df_ct['project_type'].replace({'Active':'1'}, inplace=True)
df_ct['project_type'].replace({'Compliance Complete':'2'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- written off':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- confirmed':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- Not written off':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- not written off':'0'}, inplace=True)
df_ct['project_type'].replace({'Repaid':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of Business':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- Loan repaid in full':'0'}, inplace=True)
df_ct['project_type'].replace({'Released':'0'}, inplace=True)
df_ct['project_type'].replace({'OOB':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of business- confirmed':'0'}, inplace=True)
df_ct['project_type'].replace({'Repaid early- Released':'0'}, inplace=True)
df_ct['project_type'].replace({'Out of business- written off':'0'}, inplace=True)
df_ct['project_type'].replace({'Repaid early- Released 10/2018':'2'}, inplace=True)
df_ct['project_type'].replace({'Released 10/2017':'2'}, inplace=True)
df_ct['project_type'].replace({'Repaid 1/8/2015':'2'}, inplace=True)
df_ct['project_type'].replace({'Repaid early released 6/18/2018':'2'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- repaid':'2'}, inplace=True)
df_ct['project_type'].replace({'Released 12/20/2018':'2'}, inplace=True)
df_ct['project_type'].replace({'Compliance complete':'2'}, inplace=True)
df_ct['project_type'].replace({'Company sold to Leggett & Platt':'0'}, inplace=True)
df_ct['project_type'].replace({'Repaid 11/3/2017':'2'}, inplace=True)
df_ct['project_type'].replace({'Active- Loan repaid but still w/in 10 years':'2'}, inplace=True)
df_ct['project_type'].replace({'Repaid 12/31/2017':'2'}, inplace=True)
df_ct['project_type'].replace({'Released 9/2/2015':'2'}, inplace=True)
df_ct['project_type'].replace({'Repaid early- Released 10/2013':'2'}, inplace=True)
df_ct['project_type'].replace({'Out of Business- Confirmed':'0'}, inplace=True)

# %%
#df_ct.drop(columns=['project_type'])

# %%
df_ct = df_ct.reindex(columns=['program', 'total_project_cost', 'company_funding', 'direct_assistance_awarded', 'tax_benefits_awarded', 'cont_jobs_total', 'project_type'])

# %%
df_ct
# Out:
#                              program  total_project_cost  company_funding  \
# 0     Small Business Express Program            50476.00         25238.00
# 1     Small Business Express Program           200000.00        100000.00
# 2     Small Business Express Program           533000.00        433000.00
# 3     Small Business Express Program           100000.00             0.00
# 4     Small Business Express Program          2931476.00       2531476.00
# ...                              ...                 ...              ...
# 2181  Small Business Express Program           201000.00        101000.00
# 2182  Small Business Express Program           200000.00        100000.00
# 2183  Small Business Express Program           500825.00        200825.00
# 2184  Small Business Express Program           500919.00        100919.00
# 2185  Small Business Express Program           186000.00         68000.00
#
#       direct_assistance_awarded  tax_benefits_awarded  cont_jobs_total  \
# 0                      25238.00                     0             1.00
# 1                     100000.00                     0             2.00
# 2                     100000.00                     0            48.00
# 3                     100000.00                     0             6.00
# 4                     400000.00                     0            22.00
# ...                         ...                   ...              ...
# 2181                  100000.00                     0             7.00
# 2182                  100000.00                     0            21.00
# 2183                  300000.00                     0            35.00
# 2184                  400000.00                     0            17.00
# 2185                  118000.00                     0             2.00
#
#      project_type
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ...           ...
# 2181            1
# 2182            0
# 2183            1
# 2184            1
# 2185            1
#
# [1976 rows x 7 columns]

# %%
df = df.append([df, df_ct])

# %%
df.isna().sum()
# Out:
# program                       0
# total_project_cost            0
# company_funding               0
# direct_assistance_awarded     0
# tax_benefits_awarded          0
# cont_jobs_total               0
# project_type                 19
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# program                      0
# total_project_cost           0
# company_funding              0
# direct_assistance_awarded    0
# tax_benefits_awarded         0
# cont_jobs_total              0
# project_type                 0
# dtype: int64

# %%
df
# Out:
#                                     program  total_project_cost  \
# 0                            130% Component          1750000.00
# 1                            130% Component          7706860.00
# 2         Value-Added Agriculture Component           415000.00
# 3                 High Quality Jobs Program         65242000.00
# 4     Community Economic Betterment Account         13030000.00
# ...                                     ...                 ...
# 2181         Small Business Express Program           201000.00
# 2182         Small Business Express Program           200000.00
# 2183         Small Business Express Program           500825.00
# 2184         Small Business Express Program           500919.00
# 2185         Small Business Express Program           186000.00
#
#       company_funding  direct_assistance_awarded  tax_benefits_awarded  \
# 0          1750000.00                  225000.00                     0
# 1          7706860.00                  150000.00                344047
# 2           415000.00                   60000.00                     0
# 3         65242000.00                  170000.00               4200000
# 4         11650000.00                  350000.00                893063
# ...               ...                        ...                   ...
# 2181        101000.00                  100000.00                     0
# 2182        100000.00                  100000.00                     0
# 2183        200825.00                  300000.00                     0
# 2184        100919.00                  400000.00                     0
# 2185         68000.00                  118000.00                     0
#
#       cont_jobs_total project_type
# 0              106.00            2
# 1               16.00            2
# 2                0.00            2
# 3              164.00            2
# 4               90.00            2
# ...               ...          ...
# 2181             7.00            1
# 2182            21.00            0
# 2183            35.00            1
# 2184            17.00            1
# 2185             2.00            1
#
# [3195 rows x 7 columns]

# %%
df_cat = df[['program']]
df_cat
# Out:
#                                     program
# 0                            130% Component
# 1                            130% Component
# 2         Value-Added Agriculture Component
# 3                 High Quality Jobs Program
# 4     Community Economic Betterment Account
# ...                                     ...
# 2181         Small Business Express Program
# 2182         Small Business Express Program
# 2183         Small Business Express Program
# 2184         Small Business Express Program
# 2185         Small Business Express Program
#
# [3195 rows x 1 columns]

# %%
# Make a copy of the df
X = df.copy()

#Drop our response column and categorical variables from the X df
X.drop(columns=['project_type', 'program'], inplace=True)

#Need this for labels later
X_labels = X

#Create our y/response df
y = df['project_type']

# %%
X_df = X

# %%
#One hot encode X
# create an object of the OneHotEncoder
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse=False)

#df_cat = np.reshape(df_cat.values,(-1,1))
ohe_df = ohe.fit_transform(df_cat)
X_df_cat = pd.DataFrame(ohe_df,columns=ohe.get_feature_names())

# %%
X_df_cat
# Out:
#       x0_100% Component  x0_130% Component  \
# 0                  0.00               1.00
# 1                  0.00               1.00
# 2                  0.00               0.00
# 3                  0.00               0.00
# 4                  0.00               0.00
# ...                 ...                ...
# 3190               0.00               0.00
# 3191               0.00               0.00
# 3192               0.00               0.00
# 3193               0.00               0.00
# 3194               0.00               0.00
#
#       x0_Community Economic Betterment Account  \
# 0                                         0.00
# 1                                         0.00
# 2                                         0.00
# 3                                         0.00
# 4                                         1.00
# ...                                        ...
# 3190                                      0.00
# 3191                                      0.00
# 3192                                      0.00
# 3193                                      0.00
# 3194                                      0.00
#
#       x0_Economic Development Set-Aside  x0_Enterprise Zone  \
# 0                                  0.00                0.00
# 1                                  0.00                0.00
# 2                                  0.00                0.00
# 3                                  0.00                0.00
# 4                                  0.00                0.00
# ...                                 ...                 ...
# 3190                               0.00                0.00
# 3191                               0.00                0.00
# 3192                               0.00                0.00
# 3193                               0.00                0.00
# 3194                               0.00                0.00
#
#       x0_Entrepreneurial Component  \
# 0                             0.00
# 1                             0.00
# 2                             0.00
# 3                             0.00
# 4                             0.00
# ...                            ...
# 3190                          0.00
# 3191                          0.00
# 3192                          0.00
# 3193                          0.00
# 3194                          0.00
#
#       x0_Entrepreneurial Component Technical Assistance  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Entrepreneurial Ventures Assistance  \
# 0                                       0.00
# 1                                       0.00
# 2                                       0.00
# 3                                       0.00
# 4                                       0.00
# ...                                      ...
# 3190                                    0.00
# 3191                                    0.00
# 3192                                    0.00
# 3193                                    0.00
# 3194                                    0.00
#
#       x0_Entrepreneurial Ventures Assistance Financial Assistance  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Grow Iowa Value Fund  \
# 0                        0.00
# 1                        0.00
# 2                        0.00
# 3                        0.00
# 4                        0.00
# ...                       ...
# 3190                     0.00
# 3191                     0.00
# 3192                     0.00
# 3193                     0.00
# 3194                     0.00
#
#       x0_Grow Iowa Value Fund Infrastructure Component  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 3190                                              0.00
# 3191                                              0.00
# 3192                                              0.00
# 3193                                              0.00
# 3194                                              0.00
#
#       x0_High Quality Jobs Program  x0_Manufacturing Assistance Act  \
# 0                             0.00                             0.00
# 1                             0.00                             0.00
# 2                             0.00                             0.00
# 3                             1.00                             0.00
# 4                             0.00                             0.00
# ...                            ...                              ...
# 3190                          0.00                             0.00
# 3191                          0.00                             0.00
# 3192                          0.00                             0.00
# 3193                          0.00                             0.00
# 3194                          0.00                             0.00
#
#       x0_Manufacturing Assistance Act - First Five  \
# 0                                             0.00
# 1                                             0.00
# 2                                             0.00
# 3                                             0.00
# 4                                             0.00
# ...                                            ...
# 3190                                          0.00
# 3191                                          0.00
# 3192                                          0.00
# 3193                                          0.00
# 3194                                          0.00
#
#       x0_Manufacturing Assistance Act - First Five/URA Tax Credits  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act Revolving Loan Fund  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act Revolving Loan Fund- First Five  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act- First Five  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
# 3                                            0.00
# 4                                            0.00
# ...                                           ...
# 3190                                         0.00
# 3191                                         0.00
# 3192                                         0.00
# 3193                                         0.00
# 3194                                         0.00
#
#       x0_Manufacturing Assistance Act/ URA Tax Credits  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 3190                                              0.00
# 3191                                              0.00
# 3192                                              0.00
# 3193                                              0.00
# 3194                                              0.00
#
#       x0_Manufacturing Assistance Act/MAA Revolving Loan Fund  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act/Small Business Revolving Loan Fund  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act/URA Tax Credits  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ...                                               ...
# 3190                                             0.00
# 3191                                             0.00
# 3192                                             0.00
# 3193                                             0.00
# 3194                                             0.00
#
#       x0_Opportunities and Threats  x0_Small Business Express Program  \
# 0                             0.00                               0.00
# 1                             0.00                               0.00
# 2                             0.00                               0.00
# 3                             0.00                               0.00
# 4                             0.00                               0.00
# ...                            ...                                ...
# 3190                          0.00                               1.00
# 3191                          0.00                               1.00
# 3192                          0.00                               1.00
# 3193                          0.00                               1.00
# 3194                          0.00                               1.00
#
#       x0_Targeted Jobs  x0_Value-Added Agriculture Component  \
# 0                 0.00                                  0.00
# 1                 0.00                                  0.00
# 2                 0.00                                  1.00
# 3                 0.00                                  0.00
# 4                 0.00                                  0.00
# ...                ...                                   ...
# 3190              0.00                                  0.00
# 3191              0.00                                  0.00
# 3192              0.00                                  0.00
# 3193              0.00                                  0.00
# 3194              0.00                                  0.00
#
#       x0_Value-added Agricultural Products and Process Financial Assistance Program
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
# [3195 rows x 27 columns]

# %% [raw]
# #Scale data
#
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(X)
# X_df = scaler.transform(X)

# %%
X_df = pd.DataFrame(X_df, columns=X.columns)
X_df
# Out:
#       total_project_cost  company_funding  direct_assistance_awarded  \
# 0             1750000.00       1750000.00                  225000.00
# 1             7706860.00       7706860.00                  150000.00
# 2              415000.00        415000.00                   60000.00
# 3            65242000.00      65242000.00                  170000.00
# 4            13030000.00      11650000.00                  350000.00
# ...                  ...              ...                        ...
# 2181           201000.00        101000.00                  100000.00
# 2182           200000.00        100000.00                  100000.00
# 2183           500825.00        200825.00                  300000.00
# 2184           500919.00        100919.00                  400000.00
# 2185           186000.00         68000.00                  118000.00
#
#       tax_benefits_awarded  cont_jobs_total
# 0                        0           106.00
# 1                   344047            16.00
# 2                        0             0.00
# 3                  4200000           164.00
# 4                   893063            90.00
# ...                    ...              ...
# 2181                     0             7.00
# 2182                     0            21.00
# 2183                     0            35.00
# 2184                     0            17.00
# 2185                     0             2.00
#
# [3195 rows x 5 columns]

# %%
print(X_df_cat.shape)
print(X_df.shape)

#We need to reset the index so that we can join them successfully
X_df.reset_index(inplace=True, drop=True)
#Join the categorical items back to the original
X_df = pd.concat([pd.DataFrame(X_df, columns=X_df.columns), X_df_cat], axis=1)
# Out:
# (3195, 27)
# (3195, 5)

# %%
X_labels = X_df.columns.values

X_df
# Out:
#       total_project_cost  company_funding  direct_assistance_awarded  \
# 0             1750000.00       1750000.00                  225000.00
# 1             7706860.00       7706860.00                  150000.00
# 2              415000.00        415000.00                   60000.00
# 3            65242000.00      65242000.00                  170000.00
# 4            13030000.00      11650000.00                  350000.00
# ...                  ...              ...                        ...
# 3190           201000.00        101000.00                  100000.00
# 3191           200000.00        100000.00                  100000.00
# 3192           500825.00        200825.00                  300000.00
# 3193           500919.00        100919.00                  400000.00
# 3194           186000.00         68000.00                  118000.00
#
#       tax_benefits_awarded  cont_jobs_total  x0_100% Component  \
# 0                        0           106.00               0.00
# 1                   344047            16.00               0.00
# 2                        0             0.00               0.00
# 3                  4200000           164.00               0.00
# 4                   893063            90.00               0.00
# ...                    ...              ...                ...
# 3190                     0             7.00               0.00
# 3191                     0            21.00               0.00
# 3192                     0            35.00               0.00
# 3193                     0            17.00               0.00
# 3194                     0             2.00               0.00
#
#       x0_130% Component  x0_Community Economic Betterment Account  \
# 0                  1.00                                      0.00
# 1                  1.00                                      0.00
# 2                  0.00                                      0.00
# 3                  0.00                                      0.00
# 4                  0.00                                      1.00
# ...                 ...                                       ...
# 3190               0.00                                      0.00
# 3191               0.00                                      0.00
# 3192               0.00                                      0.00
# 3193               0.00                                      0.00
# 3194               0.00                                      0.00
#
#       x0_Economic Development Set-Aside  x0_Enterprise Zone  \
# 0                                  0.00                0.00
# 1                                  0.00                0.00
# 2                                  0.00                0.00
# 3                                  0.00                0.00
# 4                                  0.00                0.00
# ...                                 ...                 ...
# 3190                               0.00                0.00
# 3191                               0.00                0.00
# 3192                               0.00                0.00
# 3193                               0.00                0.00
# 3194                               0.00                0.00
#
#       x0_Entrepreneurial Component  \
# 0                             0.00
# 1                             0.00
# 2                             0.00
# 3                             0.00
# 4                             0.00
# ...                            ...
# 3190                          0.00
# 3191                          0.00
# 3192                          0.00
# 3193                          0.00
# 3194                          0.00
#
#       x0_Entrepreneurial Component Technical Assistance  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Entrepreneurial Ventures Assistance  \
# 0                                       0.00
# 1                                       0.00
# 2                                       0.00
# 3                                       0.00
# 4                                       0.00
# ...                                      ...
# 3190                                    0.00
# 3191                                    0.00
# 3192                                    0.00
# 3193                                    0.00
# 3194                                    0.00
#
#       x0_Entrepreneurial Ventures Assistance Financial Assistance  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Grow Iowa Value Fund  \
# 0                        0.00
# 1                        0.00
# 2                        0.00
# 3                        0.00
# 4                        0.00
# ...                       ...
# 3190                     0.00
# 3191                     0.00
# 3192                     0.00
# 3193                     0.00
# 3194                     0.00
#
#       x0_Grow Iowa Value Fund Infrastructure Component  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 3190                                              0.00
# 3191                                              0.00
# 3192                                              0.00
# 3193                                              0.00
# 3194                                              0.00
#
#       x0_High Quality Jobs Program  x0_Manufacturing Assistance Act  \
# 0                             0.00                             0.00
# 1                             0.00                             0.00
# 2                             0.00                             0.00
# 3                             1.00                             0.00
# 4                             0.00                             0.00
# ...                            ...                              ...
# 3190                          0.00                             0.00
# 3191                          0.00                             0.00
# 3192                          0.00                             0.00
# 3193                          0.00                             0.00
# 3194                          0.00                             0.00
#
#       x0_Manufacturing Assistance Act - First Five  \
# 0                                             0.00
# 1                                             0.00
# 2                                             0.00
# 3                                             0.00
# 4                                             0.00
# ...                                            ...
# 3190                                          0.00
# 3191                                          0.00
# 3192                                          0.00
# 3193                                          0.00
# 3194                                          0.00
#
#       x0_Manufacturing Assistance Act - First Five/URA Tax Credits  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act Revolving Loan Fund  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act Revolving Loan Fund- First Five  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act- First Five  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
# 3                                            0.00
# 4                                            0.00
# ...                                           ...
# 3190                                         0.00
# 3191                                         0.00
# 3192                                         0.00
# 3193                                         0.00
# 3194                                         0.00
#
#       x0_Manufacturing Assistance Act/ URA Tax Credits  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 3190                                              0.00
# 3191                                              0.00
# 3192                                              0.00
# 3193                                              0.00
# 3194                                              0.00
#
#       x0_Manufacturing Assistance Act/MAA Revolving Loan Fund  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act/Small Business Revolving Loan Fund  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
#       x0_Manufacturing Assistance Act/URA Tax Credits  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ...                                               ...
# 3190                                             0.00
# 3191                                             0.00
# 3192                                             0.00
# 3193                                             0.00
# 3194                                             0.00
#
#       x0_Opportunities and Threats  x0_Small Business Express Program  \
# 0                             0.00                               0.00
# 1                             0.00                               0.00
# 2                             0.00                               0.00
# 3                             0.00                               0.00
# 4                             0.00                               0.00
# ...                            ...                                ...
# 3190                          0.00                               1.00
# 3191                          0.00                               1.00
# 3192                          0.00                               1.00
# 3193                          0.00                               1.00
# 3194                          0.00                               1.00
#
#       x0_Targeted Jobs  x0_Value-Added Agriculture Component  \
# 0                 0.00                                  0.00
# 1                 0.00                                  0.00
# 2                 0.00                                  1.00
# 3                 0.00                                  0.00
# 4                 0.00                                  0.00
# ...                ...                                   ...
# 3190              0.00                                  0.00
# 3191              0.00                                  0.00
# 3192              0.00                                  0.00
# 3193              0.00                                  0.00
# 3194              0.00                                  0.00
#
#       x0_Value-added Agricultural Products and Process Financial Assistance Program
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 3190                                               0.00
# 3191                                               0.00
# 3192                                               0.00
# 3193                                               0.00
# 3194                                               0.00
#
# [3195 rows x 32 columns]

# %%
#Create train test split
X_train, X_test, y_train, y_test = train_test_split(X_df, y, test_size=0.2)
#Remember to always work on the train set

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [raw]
# # Number of trees in random forest
# n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# # Number of features to consider at every split
# max_features = ['auto', 'sqrt']
# # Maximum number of levels in tree
# max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
# max_depth.append(None)
# # Minimum number of samples required to split a node
# min_samples_split = [2, 5, 10]
# # Minimum number of samples required at each leaf node
# min_samples_leaf = [1, 2, 4]
# # Method of selecting samples for training each tree
# bootstrap = [True, False]
# # Create the random grid
# param_grid = {'n_estimators': n_estimators,
#                'max_features': max_features,
#                'max_depth': max_depth,
#                'min_samples_split': min_samples_split,
#                'min_samples_leaf': min_samples_leaf,
#                'bootstrap': bootstrap}
# print(param_grid)

# %% [raw]
# from sklearn.ensemble import RandomForestRegressor
# rf = RandomForestRegressor()
#
# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = param_grid, n_iter = 100, cv = 3, verbose=2, n_jobs = -1)
# # Fit the random search model
# rf_random.fit(X_train, y_train)

# %% [raw]
# rf_random.best_params_

# %%
from sklearn.ensemble import RandomForestClassifier
tree_clf = RandomForestClassifier(n_estimators=800, min_samples_split = 2, min_samples_leaf = 1,
 max_features = 'auto', max_depth = 20, bootstrap = True)
tree_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=800)

# %%
#Decision Tree Regression Accuracy
from sklearn.metrics import accuracy_score

#Make prediction and check accuracy score
preds = tree_clf.predict(X_train)
acc_score = accuracy_score(preds, y_train)
print('Train Accuracy=%s' % (acc_score))
preds = tree_clf.predict(X_test)
acc_score = accuracy_score(preds, y_test)
print('Test Accuracy=%s' % (acc_score))
# Out:
# Train Accuracy=0.9370109546165885
# Test Accuracy=0.7511737089201878

# %%
from sklearn.tree import plot_tree
plot_tree(tree_clf.estimators_[0], 
          feature_names=X_df.columns,
          class_names=['failure', 'pending', 'success'], 
          filled=True, impurity=True, 
          rounded=True)
# Out:
# [Text(239.6490171318812, 212.26285714285714, 'company_funding <= 907877.5\ngini = 0.539\nsamples = 1619\nvalue = [256, 1538, 762]\nclass = pending'),
#  Text(192.05997031508693, 201.90857142857143, 'x0_Community Economic Betterment Account <= 0.5\ngini = 0.489\nsamples = 1013\nvalue = [125, 1063, 420]\nclass = pending'),
#  Text(191.32089746740482, 191.5542857142857, 'x0_High Quality Jobs Program <= 0.5\ngini = 0.487\nsamples = 1010\nvalue = [125, 1063, 415]\nclass = pending'),
#  Text(170.75884791494207, 181.2, 'x0_Value-added Agricultural Products and Process Financial Assistance Program <= 0.5\ngini = 0.476\nsamples = 962\nvalue = [108, 1033, 392]\nclass = pending'),
#  Text(170.01977506725993, 170.84571428571428, 'company_funding <= 612500.0\ngini = 0.475\nsamples = 960\nvalue = [108, 1033, 389]\nclass = pending'),
#  Text(138.64219914114238, 160.49142857142857, 'total_project_cost <= 995000.0\ngini = 0.482\nsamples = 928\nvalue = [104, 980, 388]\nclass = pending'),
#  Text(81.79963007036424, 150.13714285714286, 'x0_Economic Development Set-Aside <= 0.5\ngini = 0.474\nsamples = 918\nvalue = [93, 977, 383]\nclass = pending'),
#  Text(81.06055722268212, 139.78285714285715, 'x0_Small Business Express Program <= 0.5\ngini = 0.472\nsamples = 916\nvalue = [93, 977, 378]\nclass = pending'),
#  Text(8.129801324503312, 129.42857142857144, 'tax_benefits_awarded <= 1806749.0\ngini = 0.643\nsamples = 23\nvalue = [8, 16, 14]\nclass = pending'),
#  Text(7.3907284768211925, 119.07428571428571, 'cont_jobs_total <= 26.5\ngini = 0.611\nsamples = 22\nvalue = [5, 16, 14]\nclass = pending'),
#  Text(5.1735099337748345, 108.72, 'x0_Enterprise Zone <= 0.5\ngini = 0.566\nsamples = 15\nvalue = [5, 4, 13]\nclass = success'),
#  Text(4.434437086092715, 98.36571428571429, 'x0_Value-Added Agriculture Component <= 0.5\ngini = 0.544\nsamples = 14\nvalue = [4, 4, 13]\nclass = success'),
#  Text(3.6953642384105962, 88.01142857142858, 'direct_assistance_awarded <= 45000.0\ngini = 0.56\nsamples = 13\nvalue = [4, 4, 12]\nclass = success'),
#  Text(1.4781456953642385, 77.65714285714284, 'cont_jobs_total <= 8.0\ngini = 0.375\nsamples = 3\nvalue = [3, 1, 0]\nclass = failure'),
#  Text(0.7390728476821192, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(2.2172185430463576, 67.30285714285714, 'tax_benefits_awarded <= 37500.0\ngini = 0.444\nsamples = 2\nvalue = [2, 1, 0]\nclass = failure'),
#  Text(1.4781456953642385, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(2.956291390728477, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(5.912582781456954, 77.65714285714284, 'x0_130% Component <= 0.5\ngini = 0.398\nsamples = 10\nvalue = [1, 3, 12]\nclass = success'),
#  Text(5.1735099337748345, 67.30285714285714, 'company_funding <= 42000.0\ngini = 0.32\nsamples = 9\nvalue = [0, 3, 12]\nclass = success'),
#  Text(4.434437086092715, 56.94857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 8]\nclass = success'),
#  Text(5.912582781456954, 56.94857142857143, 'total_project_cost <= 480110.0\ngini = 0.49\nsamples = 5\nvalue = [0, 3, 4]\nclass = success'),
#  Text(5.1735099337748345, 46.59428571428572, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4]\nclass = success'),
#  Text(6.651655629139073, 46.59428571428572, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(6.651655629139073, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(5.1735099337748345, 88.01142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(5.912582781456954, 98.36571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(9.60794701986755, 108.72, 'x0_Manufacturing Assistance Act <= 0.5\ngini = 0.142\nsamples = 7\nvalue = [0, 12, 1]\nclass = pending'),
#  Text(8.86887417218543, 98.36571428571429, 'direct_assistance_awarded <= 210000.0\ngini = 0.165\nsamples = 6\nvalue = [0, 10, 1]\nclass = pending'),
#  Text(8.129801324503312, 88.01142857142858, 'direct_assistance_awarded <= 110000.0\ngini = 0.375\nsamples = 3\nvalue = [0, 3, 1]\nclass = pending'),
#  Text(7.3907284768211925, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(8.86887417218543, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(9.60794701986755, 88.01142857142858, 'gini = 0.0\nsamples = 3\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(10.347019867549669, 98.36571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(8.86887417218543, 119.07428571428571, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(153.99131312086092, 129.42857142857144, 'total_project_cost <= 717921.0\ngini = 0.465\nsamples = 893\nvalue = [85, 961, 364]\nclass = pending'),
#  Text(118.41044081125828, 119.07428571428571, 'cont_jobs_total <= 27.5\ngini = 0.462\nsamples = 869\nvalue = [85, 945, 348]\nclass = pending'),
#  Text(67.94273592715231, 108.72, 'cont_jobs_total <= 2.5\ngini = 0.482\nsamples = 724\nvalue = [81, 759, 298]\nclass = pending'),
#  Text(23.604139072847683, 98.36571428571429, 'company_funding <= 14625.0\ngini = 0.451\nsamples = 94\nvalue = [19, 104, 23]\nclass = pending'),
#  Text(15.42814569536424, 88.01142857142858, 'total_project_cost <= 221213.0\ngini = 0.606\nsamples = 34\nvalue = [9, 27, 16]\nclass = pending'),
#  Text(14.68907284768212, 77.65714285714284, 'cont_jobs_total <= 1.5\ngini = 0.628\nsamples = 32\nvalue = [9, 22, 16]\nclass = pending'),
#  Text(9.79271523178808, 67.30285714285714, 'direct_assistance_awarded <= 16000.0\ngini = 0.628\nsamples = 16\nvalue = [4, 10, 9]\nclass = pending'),
#  Text(9.053642384105961, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(10.531788079470198, 56.94857142857143, 'total_project_cost <= 99491.0\ngini = 0.58\nsamples = 15\nvalue = [2, 10, 9]\nclass = pending'),
#  Text(8.129801324503312, 46.59428571428572, 'company_funding <= 6867.5\ngini = 0.571\nsamples = 11\nvalue = [2, 8, 4]\nclass = pending'),
#  Text(7.3907284768211925, 36.24000000000001, 'direct_assistance_awarded <= 49955.0\ngini = 0.592\nsamples = 10\nvalue = [2, 7, 4]\nclass = pending'),
#  Text(5.543046357615895, 25.8857142857143, 'total_project_cost <= 35500.0\ngini = 0.444\nsamples = 4\nvalue = [0, 2, 4]\nclass = success'),
#  Text(4.803973509933775, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(6.282119205298013, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4]\nclass = success'),
#  Text(9.23841059602649, 25.8857142857143, 'total_project_cost <= 72500.0\ngini = 0.408\nsamples = 6\nvalue = [2, 5, 0]\nclass = pending'),
#  Text(7.760264900662252, 15.531428571428563, 'total_project_cost <= 60000.0\ngini = 0.32\nsamples = 4\nvalue = [1, 4, 0]\nclass = pending'),
#  Text(7.021192052980132, 5.177142857142854, 'gini = 0.375\nsamples = 3\nvalue = [1, 3, 0]\nclass = pending'),
#  Text(8.499337748344372, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(10.716556291390729, 15.531428571428563, 'direct_assistance_awarded <= 87000.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]\nclass = failure'),
#  Text(9.977483443708609, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(11.455629139072848, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(8.86887417218543, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(12.933774834437086, 46.59428571428572, 'company_funding <= 2500.0\ngini = 0.408\nsamples = 4\nvalue = [0, 2, 5]\nclass = success'),
#  Text(12.194701986754968, 36.24000000000001, 'total_project_cost <= 99991.0\ngini = 0.5\nsamples = 3\nvalue = [0, 2, 2]\nclass = pending'),
#  Text(11.455629139072848, 25.8857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(12.933774834437086, 25.8857142857143, 'total_project_cost <= 124713.0\ngini = 0.444\nsamples = 2\nvalue = [0, 2, 1]\nclass = pending'),
#  Text(12.194701986754968, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(13.672847682119206, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(13.672847682119206, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 3]\nclass = success'),
#  Text(19.58543046357616, 67.30285714285714, 'total_project_cost <= 114250.0\ngini = 0.622\nsamples = 16\nvalue = [5, 12, 7]\nclass = pending'),
#  Text(18.84635761589404, 56.94857142857143, 'direct_assistance_awarded <= 78500.0\ngini = 0.58\nsamples = 14\nvalue = [5, 12, 4]\nclass = pending'),
#  Text(17.368211920529802, 46.59428571428572, 'company_funding <= 8250.0\ngini = 0.594\nsamples = 6\nvalue = [1, 4, 3]\nclass = pending'),
#  Text(16.629139072847682, 36.24000000000001, 'company_funding <= 4000.0\ngini = 0.56\nsamples = 4\nvalue = [1, 1, 3]\nclass = success'),
#  Text(15.890066225165564, 25.8857142857143, 'company_funding <= 750.0\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1]\nclass = failure'),
#  Text(15.150993377483443, 15.531428571428563, 'total_project_cost <= 54750.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]\nclass = failure'),
#  Text(14.411920529801325, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(15.890066225165564, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(16.629139072847682, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(17.368211920529802, 25.8857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(18.107284768211922, 36.24000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(20.32450331125828, 46.59428571428572, 'direct_assistance_awarded <= 96150.0\ngini = 0.521\nsamples = 8\nvalue = [4, 8, 1]\nclass = pending'),
#  Text(19.58543046357616, 36.24000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(21.063576158940396, 36.24000000000001, 'gini = 0.562\nsamples = 6\nvalue = [4, 6, 1]\nclass = pending'),
#  Text(20.32450331125828, 56.94857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(16.167218543046356, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 5, 0]\nclass = pending'),
#  Text(31.780132450331127, 88.01142857142858, 'total_project_cost <= 454000.0\ngini = 0.312\nsamples = 60\nvalue = [10, 77, 7]\nclass = pending'),
#  Text(28.45430463576159, 77.65714285714284, 'cont_jobs_total <= 1.5\ngini = 0.273\nsamples = 57\nvalue = [10, 76, 4]\nclass = pending'),
#  Text(24.019867549668874, 67.30285714285714, 'direct_assistance_awarded <= 27500.0\ngini = 0.292\nsamples = 23\nvalue = [3, 30, 3]\nclass = pending'),
#  Text(22.541721854304637, 56.94857142857143, 'direct_assistance_awarded <= 21150.0\ngini = 0.091\nsamples = 12\nvalue = [0, 20, 1]\nclass = pending'),
#  Text(21.802649006622516, 46.59428571428572, 'gini = 0.0\nsamples = 8\nvalue = [0, 15, 0]\nclass = pending'),
#  Text(23.280794701986757, 46.59428571428572, 'direct_assistance_awarded <= 22280.0\ngini = 0.278\nsamples = 4\nvalue = [0, 5, 1]\nclass = pending'),
#  Text(22.541721854304637, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(24.019867549668874, 36.24000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 5, 0]\nclass = pending'),
#  Text(25.498013245033114, 56.94857142857143, 'cont_jobs_total <= 0.5\ngini = 0.498\nsamples = 11\nvalue = [3, 10, 2]\nclass = pending'),
#  Text(24.758940397350994, 46.59428571428572, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(26.237086092715234, 46.59428571428572, 'company_funding <= 53750.0\ngini = 0.569\nsamples = 9\nvalue = [3, 7, 2]\nclass = pending'),
#  Text(25.498013245033114, 36.24000000000001, 'direct_assistance_awarded <= 47500.0\ngini = 0.611\nsamples = 5\nvalue = [3, 1, 2]\nclass = failure'),
#  Text(24.758940397350994, 25.8857142857143, 'gini = 0.0\nsamples = 2\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(26.237086092715234, 25.8857142857143, 'direct_assistance_awarded <= 68094.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = success'),
#  Text(25.498013245033114, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(26.97615894039735, 15.531428571428563, 'company_funding <= 32250.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = pending'),
#  Text(26.237086092715234, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(27.71523178807947, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(26.97615894039735, 36.24000000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 6, 0]\nclass = pending'),
#  Text(32.8887417218543, 67.30285714285714, 'total_project_cost <= 36807.5\ngini = 0.257\nsamples = 34\nvalue = [7, 46, 1]\nclass = pending'),
#  Text(32.149668874172185, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(33.627814569536426, 56.94857142857143, 'total_project_cost <= 226950.0\ngini = 0.18\nsamples = 33\nvalue = [4, 46, 1]\nclass = pending'),
#  Text(32.8887417218543, 46.59428571428572, 'company_funding <= 72000.0\ngini = 0.224\nsamples = 27\nvalue = [4, 35, 1]\nclass = pending'),
#  Text(31.41059602649007, 36.24000000000001, 'company_funding <= 28175.0\ngini = 0.061\nsamples = 22\nvalue = [1, 31, 0]\nclass = pending'),
#  Text(30.67152317880795, 25.8857142857143, 'direct_assistance_awarded <= 30500.0\ngini = 0.142\nsamples = 9\nvalue = [1, 12, 0]\nclass = pending'),
#  Text(29.93245033112583, 15.531428571428563, 'direct_assistance_awarded <= 24750.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5, 0]\nclass = pending'),
#  Text(29.193377483443708, 5.177142857142854, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]\nclass = pending'),
#  Text(30.67152317880795, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(31.41059602649007, 15.531428571428563, 'gini = 0.0\nsamples = 3\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(32.149668874172185, 25.8857142857143, 'gini = 0.0\nsamples = 13\nvalue = [0, 19, 0]\nclass = pending'),
#  Text(34.36688741721854, 36.24000000000001, 'direct_assistance_awarded <= 87500.0\ngini = 0.594\nsamples = 5\nvalue = [3, 4, 1]\nclass = pending'),
#  Text(33.627814569536426, 25.8857142857143, 'direct_assistance_awarded <= 47500.0\ngini = 0.444\nsamples = 2\nvalue = [2, 0, 1]\nclass = failure'),
#  Text(32.8887417218543, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(34.36688741721854, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(35.105960264900666, 25.8857142857143, 'gini = 0.32\nsamples = 3\nvalue = [1, 4, 0]\nclass = pending'),
#  Text(34.36688741721854, 46.59428571428572, 'gini = 0.0\nsamples = 6\nvalue = [0, 11, 0]\nclass = pending'),
#  Text(35.105960264900666, 77.65714285714284, 'total_project_cost <= 568385.0\ngini = 0.375\nsamples = 3\nvalue = [0, 1, 3]\nclass = success'),
#  Text(34.36688741721854, 67.30285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(35.84503311258278, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(112.28133278145695, 98.36571428571429, 'company_funding <= 133312.5\ngini = 0.483\nsamples = 630\nvalue = [62, 655, 275]\nclass = pending'),
#  Text(87.44155629139073, 88.01142857142858, 'company_funding <= 132990.0\ngini = 0.501\nsamples = 506\nvalue = [57, 515, 232]\nclass = pending'),
#  Text(86.70248344370862, 77.65714285714284, 'cont_jobs_total <= 9.5\ngini = 0.5\nsamples = 504\nvalue = [57, 515, 229]\nclass = pending'),
#  Text(63.14453642384106, 67.30285714285714, 'cont_jobs_total <= 4.5\ngini = 0.492\nsamples = 281\nvalue = [20, 285, 144]\nclass = pending'),
#  Text(50.16456953642384, 56.94857142857143, 'total_project_cost <= 256125.0\ngini = 0.53\nsamples = 109\nvalue = [13, 106, 59]\nclass = pending'),
#  Text(43.79006622516557, 46.59428571428572, 'cont_jobs_total <= 3.5\ngini = 0.488\nsamples = 98\nvalue = [10, 104, 45]\nclass = pending'),
#  Text(38.4317880794702, 36.24000000000001, 'company_funding <= 13537.5\ngini = 0.432\nsamples = 46\nvalue = [6, 62, 18]\nclass = pending'),
#  Text(36.5841059602649, 25.8857142857143, 'company_funding <= 4250.0\ngini = 0.492\nsamples = 11\nvalue = [0, 9, 7]\nclass = pending'),
#  Text(35.84503311258278, 15.531428571428563, 'total_project_cost <= 63784.0\ngini = 0.459\nsamples = 10\nvalue = [0, 9, 5]\nclass = pending'),
#  Text(35.105960264900666, 5.177142857142854, 'gini = 0.408\nsamples = 4\nvalue = [0, 2, 5]\nclass = success'),
#  Text(36.5841059602649, 5.177142857142854, 'gini = 0.0\nsamples = 6\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(37.32317880794702, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(40.2794701986755, 25.8857142857143, 'total_project_cost <= 95000.0\ngini = 0.395\nsamples = 35\nvalue = [6, 53, 11]\nclass = pending'),
#  Text(38.80132450331126, 15.531428571428563, 'total_project_cost <= 42160.0\ngini = 0.111\nsamples = 15\nvalue = [0, 32, 2]\nclass = pending'),
#  Text(38.06225165562914, 5.177142857142854, 'gini = 0.26\nsamples = 5\nvalue = [0, 11, 2]\nclass = pending'),
#  Text(39.54039735099338, 5.177142857142854, 'gini = 0.0\nsamples = 10\nvalue = [0, 21, 0]\nclass = pending'),
#  Text(41.75761589403974, 15.531428571428563, 'company_funding <= 48084.5\ngini = 0.569\nsamples = 20\nvalue = [6, 21, 9]\nclass = pending'),
#  Text(41.018543046357614, 5.177142857142854, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4]\nclass = success'),
#  Text(42.496688741721854, 5.177142857142854, 'gini = 0.51\nsamples = 18\nvalue = [6, 21, 5]\nclass = pending'),
#  Text(49.148344370860926, 36.24000000000001, 'total_project_cost <= 102275.0\ngini = 0.529\nsamples = 52\nvalue = [4, 42, 27]\nclass = pending'),
#  Text(46.19205298013245, 25.8857142857143, 'total_project_cost <= 79000.0\ngini = 0.521\nsamples = 30\nvalue = [1, 22, 22]\nclass = pending'),
#  Text(44.71390728476821, 15.531428571428563, 'direct_assistance_awarded <= 33400.0\ngini = 0.499\nsamples = 14\nvalue = [1, 12, 6]\nclass = pending'),
#  Text(43.974834437086095, 5.177142857142854, 'gini = 0.561\nsamples = 10\nvalue = [1, 7, 6]\nclass = pending'),
#  Text(45.452980132450335, 5.177142857142854, 'gini = 0.0\nsamples = 4\nvalue = [0, 5, 0]\nclass = pending'),
#  Text(47.67019867549669, 15.531428571428563, 'direct_assistance_awarded <= 58750.0\ngini = 0.473\nsamples = 16\nvalue = [0, 10, 16]\nclass = success'),
#  Text(46.93112582781457, 5.177142857142854, 'gini = 0.497\nsamples = 9\nvalue = [0, 6, 7]\nclass = success'),
#  Text(48.40927152317881, 5.177142857142854, 'gini = 0.426\nsamples = 7\nvalue = [0, 4, 9]\nclass = success'),
#  Text(52.10463576158941, 25.8857142857143, 'company_funding <= 69600.0\ngini = 0.446\nsamples = 22\nvalue = [3, 20, 5]\nclass = pending'),
#  Text(50.626490066225166, 15.531428571428563, 'company_funding <= 35000.0\ngini = 0.266\nsamples = 14\nvalue = [0, 16, 3]\nclass = pending'),
#  Text(49.88741721854305, 5.177142857142854, 'gini = 0.397\nsamples = 8\nvalue = [0, 8, 3]\nclass = pending'),
#  Text(51.36556291390728, 5.177142857142854, 'gini = 0.0\nsamples = 6\nvalue = [0, 8, 0]\nclass = pending'),
#  Text(53.58278145695365, 15.531428571428563, 'direct_assistance_awarded <= 77500.0\ngini = 0.642\nsamples = 8\nvalue = [3, 4, 2]\nclass = pending'),
#  Text(52.84370860927152, 5.177142857142854, 'gini = 0.611\nsamples = 5\nvalue = [3, 2, 1]\nclass = failure'),
#  Text(54.321854304635764, 5.177142857142854, 'gini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = pending'),
#  Text(56.53907284768212, 46.59428571428572, 'cont_jobs_total <= 3.5\ngini = 0.421\nsamples = 11\nvalue = [3, 2, 14]\nclass = success'),
#  Text(55.06092715231788, 36.24000000000001, 'direct_assistance_awarded <= 270000.0\ngini = 0.346\nsamples = 6\nvalue = [0, 2, 7]\nclass = success'),
#  Text(54.321854304635764, 25.8857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5]\nclass = success'),
#  Text(55.800000000000004, 25.8857142857143, 'total_project_cost <= 385000.0\ngini = 0.5\nsamples = 3\nvalue = [0, 2, 2]\nclass = pending'),
#  Text(55.06092715231788, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(56.53907284768212, 15.531428571428563, 'gini = 0.444\nsamples = 2\nvalue = [0, 1, 2]\nclass = success'),
#  Text(58.01721854304636, 36.24000000000001, 'direct_assistance_awarded <= 293500.0\ngini = 0.42\nsamples = 5\nvalue = [3, 0, 7]\nclass = success'),
#  Text(57.27814569536424, 25.8857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4]\nclass = success'),
#  Text(58.75629139072848, 25.8857142857143, 'total_project_cost <= 415000.0\ngini = 0.5\nsamples = 3\nvalue = [3, 0, 3]\nclass = failure'),
#  Text(58.01721854304636, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(59.495364238410595, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(76.12450331125828, 56.94857142857143, 'cont_jobs_total <= 5.5\ngini = 0.465\nsamples = 172\nvalue = [7, 179, 85]\nclass = pending'),
#  Text(66.70132450331126, 46.59428571428572, 'direct_assistance_awarded <= 97700.0\ngini = 0.454\nsamples = 51\nvalue = [3, 56, 23]\nclass = pending'),
#  Text(63.19072847682119, 36.24000000000001, 'direct_assistance_awarded <= 73682.0\ngini = 0.448\nsamples = 33\nvalue = [0, 37, 19]\nclass = pending'),
#  Text(61.71258278145696, 25.8857142857143, 'direct_assistance_awarded <= 62500.0\ngini = 0.38\nsamples = 27\nvalue = [0, 35, 12]\nclass = pending'),
#  Text(60.973509933774835, 15.531428571428563, 'total_project_cost <= 97576.0\ngini = 0.426\nsamples = 22\nvalue = [0, 27, 12]\nclass = pending'),
#  Text(60.23443708609272, 5.177142857142854, 'gini = 0.495\nsamples = 15\nvalue = [0, 11, 9]\nclass = pending'),
#  Text(61.71258278145696, 5.177142857142854, 'gini = 0.266\nsamples = 7\nvalue = [0, 16, 3]\nclass = pending'),
#  Text(62.451655629139076, 15.531428571428563, 'gini = 0.0\nsamples = 5\nvalue = [0, 8, 0]\nclass = pending'),
#  Text(64.66887417218543, 25.8857142857143, 'company_funding <= 94120.0\ngini = 0.346\nsamples = 6\nvalue = [0, 2, 7]\nclass = success'),
#  Text(63.929801324503316, 15.531428571428563, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 7]\nclass = success'),
#  Text(65.40794701986755, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(70.21192052980133, 36.24000000000001, 'total_project_cost <= 185800.0\ngini = 0.429\nsamples = 18\nvalue = [3, 19, 4]\nclass = pending'),
#  Text(67.6251655629139, 25.8857142857143, 'total_project_cost <= 145000.0\ngini = 0.375\nsamples = 3\nvalue = [3, 1, 0]\nclass = failure'),
#  Text(66.8860927152318, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(68.36423841059603, 15.531428571428563, 'direct_assistance_awarded <= 135800.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]\nclass = failure'),
#  Text(67.6251655629139, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(69.10331125827815, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(72.79867549668874, 25.8857142857143, 'total_project_cost <= 203434.0\ngini = 0.298\nsamples = 15\nvalue = [0, 18, 4]\nclass = pending'),
#  Text(71.32052980132451, 15.531428571428563, 'company_funding <= 75000.0\ngini = 0.153\nsamples = 7\nvalue = [0, 11, 1]\nclass = pending'),
#  Text(70.58145695364239, 5.177142857142854, 'gini = 0.32\nsamples = 3\nvalue = [0, 4, 1]\nclass = pending'),
#  Text(72.05960264900662, 5.177142857142854, 'gini = 0.0\nsamples = 4\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(74.27682119205298, 15.531428571428563, 'total_project_cost <= 218824.0\ngini = 0.42\nsamples = 8\nvalue = [0, 7, 3]\nclass = pending'),
#  Text(73.53774834437087, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(75.0158940397351, 5.177142857142854, 'gini = 0.346\nsamples = 7\nvalue = [0, 7, 2]\nclass = pending'),
#  Text(85.5476821192053, 46.59428571428572, 'total_project_cost <= 160250.0\ngini = 0.468\nsamples = 121\nvalue = [4, 123, 62]\nclass = pending'),
#  Text(80.558940397351, 36.24000000000001, 'company_funding <= 79000.0\ngini = 0.515\nsamples = 58\nvalue = [2, 50, 40]\nclass = pending'),
#  Text(78.71125827814569, 25.8857142857143, 'cont_jobs_total <= 8.5\ngini = 0.509\nsamples = 52\nvalue = [2, 48, 34]\nclass = pending'),
#  Text(77.23311258278146, 15.531428571428563, 'cont_jobs_total <= 7.5\ngini = 0.528\nsamples = 37\nvalue = [2, 32, 27]\nclass = pending'),
#  Text(76.49403973509934, 5.177142857142854, 'gini = 0.489\nsamples = 27\nvalue = [0, 27, 20]\nclass = pending'),
#  Text(77.97218543046358, 5.177142857142854, 'gini = 0.602\nsamples = 10\nvalue = [2, 5, 7]\nclass = success'),
#  Text(80.18940397350994, 15.531428571428563, 'company_funding <= 41600.0\ngini = 0.423\nsamples = 15\nvalue = [0, 16, 7]\nclass = pending'),
#  Text(79.45033112582782, 5.177142857142854, 'gini = 0.496\nsamples = 6\nvalue = [0, 6, 5]\nclass = pending'),
#  Text(80.92847682119205, 5.177142857142854, 'gini = 0.278\nsamples = 9\nvalue = [0, 10, 2]\nclass = pending'),
#  Text(82.4066225165563, 25.8857142857143, 'direct_assistance_awarded <= 37500.0\ngini = 0.375\nsamples = 6\nvalue = [0, 2, 6]\nclass = success'),
#  Text(81.66754966887417, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(83.1456953642384, 15.531428571428563, 'cont_jobs_total <= 8.5\ngini = 0.48\nsamples = 4\nvalue = [0, 2, 3]\nclass = success'),
#  Text(82.4066225165563, 5.177142857142854, 'gini = 0.375\nsamples = 3\nvalue = [0, 1, 3]\nclass = success'),
#  Text(83.88476821192053, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(90.5364238410596, 36.24000000000001, 'cont_jobs_total <= 7.5\ngini = 0.382\nsamples = 63\nvalue = [2, 73, 22]\nclass = pending'),
#  Text(87.58013245033113, 25.8857142857143, 'cont_jobs_total <= 6.5\ngini = 0.425\nsamples = 40\nvalue = [1, 43, 17]\nclass = pending'),
#  Text(86.10198675496689, 15.531428571428563, 'company_funding <= 95000.0\ngini = 0.389\nsamples = 21\nvalue = [1, 24, 7]\nclass = pending'),
#  Text(85.36291390728478, 5.177142857142854, 'gini = 0.133\nsamples = 9\nvalue = [0, 13, 1]\nclass = pending'),
#  Text(86.84105960264901, 5.177142857142854, 'gini = 0.512\nsamples = 12\nvalue = [1, 11, 6]\nclass = pending'),
#  Text(89.05827814569537, 15.531428571428563, 'company_funding <= 100750.0\ngini = 0.452\nsamples = 19\nvalue = [0, 19, 10]\nclass = pending'),
#  Text(88.31920529801324, 5.177142857142854, 'gini = 0.403\nsamples = 17\nvalue = [0, 18, 7]\nclass = pending'),
#  Text(89.79735099337749, 5.177142857142854, 'gini = 0.375\nsamples = 2\nvalue = [0, 1, 3]\nclass = success'),
#  Text(93.49271523178808, 25.8857142857143, 'cont_jobs_total <= 8.5\ngini = 0.285\nsamples = 23\nvalue = [1, 30, 5]\nclass = pending'),
#  Text(92.01456953642385, 15.531428571428563, 'direct_assistance_awarded <= 212553.0\ngini = 0.234\nsamples = 15\nvalue = [1, 20, 2]\nclass = pending'),
#  Text(91.27549668874173, 5.177142857142854, 'gini = 0.357\nsamples = 10\nvalue = [1, 11, 2]\nclass = pending'),
#  Text(92.75364238410596, 5.177142857142854, 'gini = 0.0\nsamples = 5\nvalue = [0, 9, 0]\nclass = pending'),
#  Text(94.97086092715232, 15.531428571428563, 'direct_assistance_awarded <= 99842.0\ngini = 0.355\nsamples = 8\nvalue = [0, 10, 3]\nclass = pending'),
#  Text(94.2317880794702, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(95.70993377483444, 5.177142857142854, 'gini = 0.278\nsamples = 7\nvalue = [0, 10, 2]\nclass = pending'),
#  Text(110.26043046357616, 67.30285714285714, 'company_funding <= 45750.0\ngini = 0.504\nsamples = 223\nvalue = [37, 230, 85]\nclass = pending'),
#  Text(104.30165562913908, 56.94857142857143, 'direct_assistance_awarded <= 265000.0\ngini = 0.364\nsamples = 57\nvalue = [3, 68, 17]\nclass = pending'),
#  Text(99.59006622516557, 46.59428571428572, 'total_project_cost <= 61625.0\ngini = 0.301\nsamples = 49\nvalue = [3, 61, 10]\nclass = pending'),
#  Text(96.44900662251656, 36.24000000000001, 'company_funding <= 20887.0\ngini = 0.604\nsamples = 7\nvalue = [3, 7, 3]\nclass = pending'),
#  Text(95.70993377483444, 25.8857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(97.18807947019867, 25.8857142857143, 'direct_assistance_awarded <= 24250.0\ngini = 0.5\nsamples = 3\nvalue = [3, 0, 3]\nclass = failure'),
#  Text(96.44900662251656, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(97.9271523178808, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(102.73112582781457, 36.24000000000001, 'company_funding <= 28300.5\ngini = 0.203\nsamples = 42\nvalue = [0, 54, 7]\nclass = pending'),
#  Text(100.88344370860928, 25.8857142857143, 'total_project_cost <= 89068.5\ngini = 0.278\nsamples = 26\nvalue = [0, 30, 6]\nclass = pending'),
#  Text(99.40529801324503, 15.531428571428563, 'total_project_cost <= 76818.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = pending'),
#  Text(98.66622516556292, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(100.14437086092715, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(102.36158940397351, 15.531428571428563, 'total_project_cost <= 137500.0\ngini = 0.251\nsamples = 24\nvalue = [0, 29, 5]\nclass = pending'),
#  Text(101.62251655629139, 5.177142857142854, 'gini = 0.0\nsamples = 10\nvalue = [0, 12, 0]\nclass = pending'),
#  Text(103.10066225165563, 5.177142857142854, 'gini = 0.351\nsamples = 14\nvalue = [0, 17, 5]\nclass = pending'),
#  Text(104.57880794701987, 25.8857142857143, 'company_funding <= 40127.5\ngini = 0.077\nsamples = 16\nvalue = [0, 24, 1]\nclass = pending'),
#  Text(103.83973509933774, 15.531428571428563, 'gini = 0.0\nsamples = 12\nvalue = [0, 18, 0]\nclass = pending'),
#  Text(105.31788079470199, 15.531428571428563, 'company_funding <= 40850.0\ngini = 0.245\nsamples = 4\nvalue = [0, 6, 1]\nclass = pending'),
#  Text(104.57880794701987, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(106.05695364238412, 5.177142857142854, 'gini = 0.0\nsamples = 3\nvalue = [0, 6, 0]\nclass = pending'),
#  Text(109.01324503311258, 46.59428571428572, 'company_funding <= 32400.0\ngini = 0.5\nsamples = 8\nvalue = [0, 7, 7]\nclass = pending'),
#  Text(108.27417218543047, 36.24000000000001, 'direct_assistance_awarded <= 305000.0\ngini = 0.42\nsamples = 7\nvalue = [0, 3, 7]\nclass = success'),
#  Text(107.53509933774835, 25.8857142857143, 'cont_jobs_total <= 15.0\ngini = 0.346\nsamples = 6\nvalue = [0, 2, 7]\nclass = success'),
#  Text(106.79602649006623, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4]\nclass = success'),
#  Text(108.27417218543047, 15.531428571428563, 'total_project_cost <= 299275.0\ngini = 0.48\nsamples = 4\nvalue = [0, 2, 3]\nclass = success'),
#  Text(107.53509933774835, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(109.01324503311258, 5.177142857142854, 'gini = 0.5\nsamples = 3\nvalue = [0, 2, 2]\nclass = pending'),
#  Text(109.01324503311258, 25.8857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(109.7523178807947, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 4, 0]\nclass = pending'),
#  Text(116.21920529801325, 56.94857142857143, 'company_funding <= 51587.5\ngini = 0.541\nsamples = 166\nvalue = [34, 162, 68]\nclass = pending'),
#  Text(112.70860927152319, 46.59428571428572, 'direct_assistance_awarded <= 225000.0\ngini = 0.5\nsamples = 16\nvalue = [0, 14, 14]\nclass = pending'),
#  Text(111.23046357615894, 36.24000000000001, 'company_funding <= 50705.5\ngini = 0.32\nsamples = 8\nvalue = [0, 8, 2]\nclass = pending'),
#  Text(110.49139072847683, 25.8857142857143, 'gini = 0.0\nsamples = 7\nvalue = [0, 8, 0]\nclass = pending'),
#  Text(111.96953642384106, 25.8857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(114.18675496688742, 36.24000000000001, 'total_project_cost <= 332500.0\ngini = 0.444\nsamples = 8\nvalue = [0, 6, 12]\nclass = success'),
#  Text(113.4476821192053, 25.8857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 10]\nclass = success'),
#  Text(114.92582781456954, 25.8857142857143, 'direct_assistance_awarded <= 349370.0\ngini = 0.375\nsamples = 5\nvalue = [0, 6, 2]\nclass = pending'),
#  Text(114.18675496688742, 15.531428571428563, 'gini = 0.0\nsamples = 4\nvalue = [0, 6, 0]\nclass = pending'),
#  Text(115.66490066225165, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(119.72980132450331, 46.59428571428572, 'company_funding <= 53187.5\ngini = 0.534\nsamples = 150\nvalue = [34, 148, 54]\nclass = pending'),
#  Text(118.99072847682119, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(120.46887417218544, 36.24000000000001, 'cont_jobs_total <= 26.5\ngini = 0.525\nsamples = 149\nvalue = [31, 148, 54]\nclass = pending'),
#  Text(118.62119205298013, 25.8857142857143, 'total_project_cost <= 237080.0\ngini = 0.522\nsamples = 146\nvalue = [31, 147, 52]\nclass = pending'),
#  Text(117.1430463576159, 15.531428571428563, 'company_funding <= 110034.0\ngini = 0.578\nsamples = 81\nvalue = [19, 68, 33]\nclass = pending'),
#  Text(116.40397350993378, 5.177142857142854, 'gini = 0.572\nsamples = 75\nvalue = [19, 65, 28]\nclass = pending'),
#  Text(117.88211920529801, 5.177142857142854, 'gini = 0.469\nsamples = 6\nvalue = [0, 3, 5]\nclass = success'),
#  Text(120.09933774834437, 15.531428571428563, 'company_funding <= 88045.5\ngini = 0.442\nsamples = 65\nvalue = [12, 79, 19]\nclass = pending'),
#  Text(119.36026490066226, 5.177142857142854, 'gini = 0.077\nsamples = 13\nvalue = [1, 24, 0]\nclass = pending'),
#  Text(120.83841059602649, 5.177142857142854, 'gini = 0.515\nsamples = 52\nvalue = [11, 55, 19]\nclass = pending'),
#  Text(122.31655629139073, 25.8857142857143, 'direct_assistance_awarded <= 375000.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = success'),
#  Text(121.57748344370862, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = success'),
#  Text(123.05562913907285, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(88.18062913907285, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(137.12110927152318, 88.01142857142858, 'company_funding <= 524344.0\ngini = 0.392\nsamples = 124\nvalue = [5, 140, 43]\nclass = pending'),
#  Text(136.38203642384107, 77.65714285714284, 'cont_jobs_total <= 3.5\ngini = 0.384\nsamples = 123\nvalue = [5, 140, 41]\nclass = pending'),
#  Text(130.26158940397352, 67.30285714285714, 'total_project_cost <= 454902.0\ngini = 0.5\nsamples = 9\nvalue = [0, 7, 7]\nclass = pending'),
#  Text(129.5225165562914, 56.94857142857143, 'direct_assistance_awarded <= 87500.0\ngini = 0.42\nsamples = 6\nvalue = [0, 7, 3]\nclass = pending'),
#  Text(128.78344370860927, 46.59428571428572, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(130.26158940397352, 46.59428571428572, 'gini = 0.0\nsamples = 4\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(131.00066225165563, 56.94857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4]\nclass = success'),
#  Text(142.50248344370863, 67.30285714285714, 'cont_jobs_total <= 19.5\ngini = 0.362\nsamples = 114\nvalue = [5, 133, 34]\nclass = pending'),
#  Text(136.08178807947021, 56.94857142857143, 'direct_assistance_awarded <= 220408.5\ngini = 0.312\nsamples = 95\nvalue = [3, 117, 24]\nclass = pending'),
#  Text(131.73973509933776, 46.59428571428572, 'total_project_cost <= 444046.0\ngini = 0.374\nsamples = 60\nvalue = [3, 68, 18]\nclass = pending'),
#  Text(128.59867549668874, 36.24000000000001, 'cont_jobs_total <= 14.5\ngini = 0.435\nsamples = 50\nvalue = [2, 47, 18]\nclass = pending'),
#  Text(126.01192052980133, 25.8857142857143, 'company_funding <= 170810.0\ngini = 0.484\nsamples = 41\nvalue = [2, 34, 17]\nclass = pending'),
#  Text(124.5337748344371, 15.531428571428563, 'total_project_cost <= 239050.0\ngini = 0.408\nsamples = 23\nvalue = [2, 23, 6]\nclass = pending'),
#  Text(123.79470198675497, 5.177142857142854, 'gini = 0.124\nsamples = 9\nvalue = [1, 14, 0]\nclass = pending'),
#  Text(125.2728476821192, 5.177142857142854, 'gini = 0.539\nsamples = 14\nvalue = [1, 9, 6]\nclass = pending'),
#  Text(127.49006622516556, 15.531428571428563, 'cont_jobs_total <= 10.5\ngini = 0.5\nsamples = 18\nvalue = [0, 11, 11]\nclass = pending'),
#  Text(126.75099337748345, 5.177142857142854, 'gini = 0.397\nsamples = 10\nvalue = [0, 8, 3]\nclass = pending'),
#  Text(128.2291390728477, 5.177142857142854, 'gini = 0.397\nsamples = 8\nvalue = [0, 3, 8]\nclass = success'),
#  Text(131.18543046357615, 25.8857142857143, 'direct_assistance_awarded <= 90000.0\ngini = 0.133\nsamples = 9\nvalue = [0, 13, 1]\nclass = pending'),
#  Text(130.44635761589404, 15.531428571428563, 'total_project_cost <= 307760.0\ngini = 0.375\nsamples = 3\nvalue = [0, 3, 1]\nclass = pending'),
#  Text(129.70728476821193, 5.177142857142854, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(131.18543046357615, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(131.9245033112583, 15.531428571428563, 'gini = 0.0\nsamples = 6\nvalue = [0, 10, 0]\nclass = pending'),
#  Text(134.88079470198676, 36.24000000000001, 'cont_jobs_total <= 7.0\ngini = 0.087\nsamples = 10\nvalue = [1, 21, 0]\nclass = pending'),
#  Text(134.14172185430465, 25.8857142857143, 'company_funding <= 401600.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]\nclass = failure'),
#  Text(133.4026490066225, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(134.88079470198676, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(135.61986754966887, 25.8857142857143, 'gini = 0.0\nsamples = 8\nvalue = [0, 20, 0]\nclass = pending'),
#  Text(140.42384105960267, 46.59428571428572, 'cont_jobs_total <= 7.5\ngini = 0.194\nsamples = 35\nvalue = [0, 49, 6]\nclass = pending'),
#  Text(137.83708609271523, 36.24000000000001, 'direct_assistance_awarded <= 390000.0\ngini = 0.074\nsamples = 14\nvalue = [0, 25, 1]\nclass = pending'),
#  Text(137.09801324503312, 25.8857142857143, 'gini = 0.0\nsamples = 7\nvalue = [0, 14, 0]\nclass = pending'),
#  Text(138.57615894039736, 25.8857142857143, 'cont_jobs_total <= 5.5\ngini = 0.153\nsamples = 7\nvalue = [0, 11, 1]\nclass = pending'),
#  Text(137.83708609271523, 15.531428571428563, 'cont_jobs_total <= 4.5\ngini = 0.198\nsamples = 5\nvalue = [0, 8, 1]\nclass = pending'),
#  Text(137.09801324503312, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(138.57615894039736, 5.177142857142854, 'gini = 0.245\nsamples = 4\nvalue = [0, 6, 1]\nclass = pending'),
#  Text(139.31523178807947, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(143.01059602649008, 36.24000000000001, 'direct_assistance_awarded <= 399822.5\ngini = 0.285\nsamples = 21\nvalue = [0, 24, 5]\nclass = pending'),
#  Text(141.53245033112583, 25.8857142857143, 'cont_jobs_total <= 15.0\ngini = 0.083\nsamples = 16\nvalue = [0, 22, 1]\nclass = pending'),
#  Text(140.79337748344372, 15.531428571428563, 'gini = 0.0\nsamples = 11\nvalue = [0, 14, 0]\nclass = pending'),
#  Text(142.27152317880794, 15.531428571428563, 'company_funding <= 200612.0\ngini = 0.198\nsamples = 5\nvalue = [0, 8, 1]\nclass = pending'),
#  Text(141.53245033112583, 5.177142857142854, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = pending'),
#  Text(143.01059602649008, 5.177142857142854, 'gini = 0.0\nsamples = 3\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(144.4887417218543, 25.8857142857143, 'company_funding <= 197293.5\ngini = 0.444\nsamples = 5\nvalue = [0, 2, 4]\nclass = success'),
#  Text(143.7496688741722, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(145.22781456953643, 15.531428571428563, 'total_project_cost <= 609290.0\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = pending'),
#  Text(144.4887417218543, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(145.96688741721854, 5.177142857142854, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = pending'),
#  Text(148.923178807947, 56.94857142857143, 'company_funding <= 175150.0\ngini = 0.541\nsamples = 19\nvalue = [2, 16, 10]\nclass = pending'),
#  Text(148.1841059602649, 46.59428571428572, 'gini = 0.0\nsamples = 5\nvalue = [0, 8, 0]\nclass = pending'),
#  Text(149.66225165562915, 46.59428571428572, 'total_project_cost <= 582700.0\ngini = 0.58\nsamples = 14\nvalue = [2, 8, 10]\nclass = success'),
#  Text(148.923178807947, 36.24000000000001, 'cont_jobs_total <= 26.0\ngini = 0.449\nsamples = 9\nvalue = [2, 2, 10]\nclass = success'),
#  Text(147.4450331125828, 25.8857142857143, 'cont_jobs_total <= 21.5\ngini = 0.298\nsamples = 7\nvalue = [2, 0, 9]\nclass = success'),
#  Text(146.70596026490065, 15.531428571428563, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5]\nclass = success'),
#  Text(148.1841059602649, 15.531428571428563, 'cont_jobs_total <= 23.0\ngini = 0.444\nsamples = 4\nvalue = [2, 0, 4]\nclass = success'),
#  Text(147.4450331125828, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(148.923178807947, 5.177142857142854, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 4]\nclass = success'),
#  Text(150.40132450331126, 25.8857142857143, 'total_project_cost <= 415131.0\ngini = 0.444\nsamples = 2\nvalue = [0, 2, 1]\nclass = pending'),
#  Text(149.66225165562915, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(151.14039735099337, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(150.40132450331126, 36.24000000000001, 'gini = 0.0\nsamples = 5\nvalue = [0, 6, 0]\nclass = pending'),
#  Text(137.8601821192053, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(168.87814569536425, 108.72, 'total_project_cost <= 310522.5\ngini = 0.356\nsamples = 145\nvalue = [4, 186, 50]\nclass = pending'),
#  Text(157.6996688741722, 98.36571428571429, 'company_funding <= 38410.5\ngini = 0.241\nsamples = 74\nvalue = [2, 107, 15]\nclass = pending'),
#  Text(152.61854304635762, 88.01142857142858, 'cont_jobs_total <= 34.0\ngini = 0.43\nsamples = 11\nvalue = [0, 11, 5]\nclass = pending'),
#  Text(150.40132450331126, 77.65714285714284, 'direct_assistance_awarded <= 82500.0\ngini = 0.375\nsamples = 3\nvalue = [0, 1, 3]\nclass = success'),
#  Text(149.66225165562915, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(151.14039735099337, 67.30285714285714, 'cont_jobs_total <= 30.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = pending'),
#  Text(150.40132450331126, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(151.8794701986755, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(154.83576158940397, 77.65714285714284, 'cont_jobs_total <= 57.0\ngini = 0.278\nsamples = 8\nvalue = [0, 10, 2]\nclass = pending'),
#  Text(154.09668874172186, 67.30285714285714, 'company_funding <= 23500.0\ngini = 0.165\nsamples = 7\nvalue = [0, 10, 1]\nclass = pending'),
#  Text(153.35761589403975, 56.94857142857143, 'gini = 0.0\nsamples = 5\nvalue = [0, 8, 0]\nclass = pending'),
#  Text(154.83576158940397, 56.94857142857143, 'direct_assistance_awarded <= 34865.5\ngini = 0.444\nsamples = 2\nvalue = [0, 2, 1]\nclass = pending'),
#  Text(154.09668874172186, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(155.5748344370861, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(155.5748344370861, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(162.78079470198676, 88.01142857142858, 'direct_assistance_awarded <= 95000.0\ngini = 0.201\nsamples = 63\nvalue = [2, 96, 10]\nclass = pending'),
#  Text(157.79205298013247, 77.65714285714284, 'direct_assistance_awarded <= 63500.0\ngini = 0.138\nsamples = 25\nvalue = [2, 38, 1]\nclass = pending'),
#  Text(157.05298013245033, 67.30285714285714, 'direct_assistance_awarded <= 55000.0\ngini = 0.254\nsamples = 13\nvalue = [2, 18, 1]\nclass = pending'),
#  Text(156.31390728476822, 56.94857142857143, 'gini = 0.0\nsamples = 10\nvalue = [0, 17, 0]\nclass = pending'),
#  Text(157.79205298013247, 56.94857142857143, 'cont_jobs_total <= 38.5\ngini = 0.625\nsamples = 3\nvalue = [2, 1, 1]\nclass = failure'),
#  Text(157.05298013245033, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(158.53112582781458, 46.59428571428572, 'total_project_cost <= 164515.0\ngini = 0.444\nsamples = 2\nvalue = [2, 0, 1]\nclass = failure'),
#  Text(157.79205298013247, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(159.2701986754967, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(158.53112582781458, 67.30285714285714, 'gini = 0.0\nsamples = 12\nvalue = [0, 20, 0]\nclass = pending'),
#  Text(167.76953642384106, 77.65714285714284, 'direct_assistance_awarded <= 148411.0\ngini = 0.233\nsamples = 38\nvalue = [0, 58, 9]\nclass = pending'),
#  Text(167.03046357615895, 67.30285714285714, 'cont_jobs_total <= 62.5\ngini = 0.252\nsamples = 34\nvalue = [0, 52, 9]\nclass = pending'),
#  Text(164.44370860927154, 56.94857142857143, 'cont_jobs_total <= 33.5\ngini = 0.204\nsamples = 30\nvalue = [0, 46, 6]\nclass = pending'),
#  Text(161.48741721854304, 46.59428571428572, 'company_funding <= 114800.0\ngini = 0.291\nsamples = 11\nvalue = [0, 14, 3]\nclass = pending'),
#  Text(160.74834437086093, 36.24000000000001, 'company_funding <= 100070.0\ngini = 0.42\nsamples = 7\nvalue = [0, 7, 3]\nclass = pending'),
#  Text(160.00927152317882, 25.8857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 6, 0]\nclass = pending'),
#  Text(161.48741721854304, 25.8857142857143, 'total_project_cost <= 201570.0\ngini = 0.375\nsamples = 3\nvalue = [0, 1, 3]\nclass = success'),
#  Text(160.74834437086093, 15.531428571428563, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(162.22649006622518, 15.531428571428563, 'cont_jobs_total <= 29.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]\nclass = pending'),
#  Text(161.48741721854304, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(162.9655629139073, 5.177142857142854, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(162.22649006622518, 36.24000000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 7, 0]\nclass = pending'),
#  Text(167.4, 46.59428571428572, 'total_project_cost <= 237225.0\ngini = 0.157\nsamples = 19\nvalue = [0, 32, 3]\nclass = pending'),
#  Text(166.6609271523179, 36.24000000000001, 'company_funding <= 127663.0\ngini = 0.211\nsamples = 15\nvalue = [0, 22, 3]\nclass = pending'),
#  Text(165.92185430463576, 25.8857142857143, 'total_project_cost <= 207100.0\ngini = 0.153\nsamples = 14\nvalue = [0, 22, 2]\nclass = pending'),
#  Text(165.18278145695365, 15.531428571428563, 'cont_jobs_total <= 45.0\ngini = 0.18\nsamples = 12\nvalue = [0, 18, 2]\nclass = pending'),
#  Text(164.44370860927154, 5.177142857142854, 'gini = 0.0\nsamples = 8\nvalue = [0, 13, 0]\nclass = pending'),
#  Text(165.92185430463576, 5.177142857142854, 'gini = 0.408\nsamples = 4\nvalue = [0, 5, 2]\nclass = pending'),
#  Text(166.6609271523179, 15.531428571428563, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0]\nclass = pending'),
#  Text(167.4, 25.8857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(168.13907284768212, 36.24000000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 10, 0]\nclass = pending'),
# ...
#  Text(288.60794701986754, 67.30285714285714, 'company_funding <= 73394328.0\ngini = 0.5\nsamples = 3\nvalue = [2, 0, 2]\nclass = failure'),
#  Text(287.86887417218543, 56.94857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(289.3470198675497, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(294.1509933774835, 98.36571428571429, 'tax_benefits_awarded <= 1483250.0\ngini = 0.569\nsamples = 36\nvalue = [18, 27, 5]\nclass = pending'),
#  Text(292.30331125827814, 88.01142857142858, 'tax_benefits_awarded <= 111499.5\ngini = 0.635\nsamples = 17\nvalue = [11, 8, 5]\nclass = failure'),
#  Text(291.56423841059603, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = success'),
#  Text(293.04238410596025, 77.65714285714284, 'company_funding <= 20398618.0\ngini = 0.599\nsamples = 15\nvalue = [11, 8, 3]\nclass = failure'),
#  Text(291.56423841059603, 67.30285714285714, 'cont_jobs_total <= 153.0\ngini = 0.444\nsamples = 7\nvalue = [4, 8, 0]\nclass = pending'),
#  Text(290.8251655629139, 56.94857142857143, 'company_funding <= 8000000.0\ngini = 0.49\nsamples = 5\nvalue = [4, 3, 0]\nclass = failure'),
#  Text(290.0860927152318, 46.59428571428572, 'gini = 0.0\nsamples = 2\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(291.56423841059603, 46.59428571428572, 'tax_benefits_awarded <= 1029375.0\ngini = 0.375\nsamples = 3\nvalue = [1, 3, 0]\nclass = pending'),
#  Text(290.8251655629139, 36.24000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(292.30331125827814, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(292.30331125827814, 56.94857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 5, 0]\nclass = pending'),
#  Text(294.5205298013245, 67.30285714285714, 'cont_jobs_total <= 90.5\ngini = 0.42\nsamples = 8\nvalue = [7, 0, 3]\nclass = failure'),
#  Text(293.7814569536424, 56.94857142857143, 'gini = 0.0\nsamples = 3\nvalue = [4, 0, 0]\nclass = failure'),
#  Text(295.25960264900664, 56.94857142857143, 'company_funding <= 25375676.0\ngini = 0.5\nsamples = 5\nvalue = [3, 0, 3]\nclass = failure'),
#  Text(294.5205298013245, 46.59428571428572, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 3]\nclass = success'),
#  Text(295.99867549668875, 46.59428571428572, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(295.99867549668875, 88.01142857142858, 'total_project_cost <= 36867500.0\ngini = 0.393\nsamples = 19\nvalue = [7, 19, 0]\nclass = pending'),
#  Text(295.25960264900664, 77.65714285714284, 'gini = 0.0\nsamples = 6\nvalue = [0, 9, 0]\nclass = pending'),
#  Text(296.73774834437086, 77.65714285714284, 'company_funding <= 30550000.0\ngini = 0.484\nsamples = 13\nvalue = [7, 10, 0]\nclass = pending'),
#  Text(295.99867549668875, 67.30285714285714, 'gini = 0.0\nsamples = 5\nvalue = [7, 0, 0]\nclass = failure'),
#  Text(297.47682119205297, 67.30285714285714, 'gini = 0.0\nsamples = 8\nvalue = [0, 10, 0]\nclass = pending'),
#  Text(299.3245033112583, 119.07428571428571, 'company_funding <= 77170000.0\ngini = 0.654\nsamples = 16\nvalue = [14, 10, 9]\nclass = failure'),
#  Text(297.47682119205297, 108.72, 'tax_benefits_awarded <= 10171000.0\ngini = 0.375\nsamples = 6\nvalue = [0, 3, 9]\nclass = success'),
#  Text(296.73774834437086, 98.36571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 9]\nclass = success'),
#  Text(298.21589403973513, 98.36571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(301.17218543046357, 108.72, 'cont_jobs_total <= 218.5\ngini = 0.444\nsamples = 10\nvalue = [14, 7, 0]\nclass = failure'),
#  Text(299.69403973509935, 98.36571428571429, 'tax_benefits_awarded <= 7852600.0\ngini = 0.337\nsamples = 7\nvalue = [11, 3, 0]\nclass = failure'),
#  Text(298.95496688741724, 88.01142857142858, 'cont_jobs_total <= 7.0\ngini = 0.375\nsamples = 3\nvalue = [1, 3, 0]\nclass = pending'),
#  Text(298.21589403973513, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(299.69403973509935, 77.65714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(300.43311258278146, 88.01142857142858, 'gini = 0.0\nsamples = 4\nvalue = [10, 0, 0]\nclass = failure'),
#  Text(302.65033112582785, 98.36571428571429, 'total_project_cost <= 188650000.0\ngini = 0.49\nsamples = 3\nvalue = [3, 4, 0]\nclass = pending'),
#  Text(301.9112582781457, 88.01142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(303.38940397350996, 88.01142857142858, 'gini = 0.375\nsamples = 2\nvalue = [3, 1, 0]\nclass = failure'),
#  Text(290.2131208609272, 129.42857142857144, 'gini = 0.0\nsamples = 12\nvalue = [0, 18, 0]\nclass = pending'),
#  Text(315.56100993377487, 139.78285714285715, 'total_project_cost <= 2436764.0\ngini = 0.608\nsamples = 100\nvalue = [26, 82, 55]\nclass = pending'),
#  Text(306.3456953642384, 129.42857142857144, 'tax_benefits_awarded <= 86400.0\ngini = 0.635\nsamples = 15\nvalue = [8, 4, 9]\nclass = success'),
#  Text(305.6066225165563, 119.07428571428571, 'company_funding <= 1887500.0\ngini = 0.625\nsamples = 12\nvalue = [8, 4, 4]\nclass = failure'),
#  Text(304.8675496688742, 108.72, 'direct_assistance_awarded <= 115000.0\ngini = 0.444\nsamples = 10\nvalue = [8, 4, 0]\nclass = failure'),
#  Text(304.12847682119207, 98.36571428571429, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]\nclass = failure'),
#  Text(305.6066225165563, 98.36571428571429, 'total_project_cost <= 1392900.0\ngini = 0.5\nsamples = 6\nvalue = [4, 4, 0]\nclass = failure'),
#  Text(304.8675496688742, 88.01142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(306.3456953642384, 88.01142857142858, 'cont_jobs_total <= 24.5\ngini = 0.444\nsamples = 4\nvalue = [4, 2, 0]\nclass = failure'),
#  Text(305.6066225165563, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(307.08476821192056, 77.65714285714284, 'direct_assistance_awarded <= 175000.0\ngini = 0.5\nsamples = 3\nvalue = [2, 2, 0]\nclass = failure'),
#  Text(306.3456953642384, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(307.82384105960267, 67.30285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(306.3456953642384, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 4]\nclass = success'),
#  Text(307.08476821192056, 119.07428571428571, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 5]\nclass = success'),
#  Text(324.7763245033113, 129.42857142857144, 'tax_benefits_awarded <= 3166188.0\ngini = 0.577\nsamples = 85\nvalue = [18, 78, 46]\nclass = pending'),
#  Text(320.6652317880795, 119.07428571428571, 'direct_assistance_awarded <= 485000.0\ngini = 0.56\nsamples = 82\nvalue = [17, 78, 39]\nclass = pending'),
#  Text(314.66026490066224, 108.72, 'company_funding <= 1195000.0\ngini = 0.477\nsamples = 58\nvalue = [5, 63, 27]\nclass = pending'),
#  Text(313.92119205298013, 98.36571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(315.3993377483444, 98.36571428571429, 'cont_jobs_total <= 39.0\ngini = 0.456\nsamples = 56\nvalue = [3, 63, 27]\nclass = pending'),
#  Text(311.5192052980133, 88.01142857142858, 'tax_benefits_awarded <= 140763.0\ngini = 0.536\nsamples = 30\nvalue = [2, 22, 25]\nclass = success'),
#  Text(310.041059602649, 77.65714285714284, 'cont_jobs_total <= 35.0\ngini = 0.153\nsamples = 6\nvalue = [0, 11, 1]\nclass = pending'),
#  Text(309.3019867549669, 67.30285714285714, 'gini = 0.0\nsamples = 5\nvalue = [0, 11, 0]\nclass = pending'),
#  Text(310.7801324503311, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = success'),
#  Text(312.9973509933775, 77.65714285714284, 'total_project_cost <= 3481250.0\ngini = 0.488\nsamples = 24\nvalue = [2, 11, 24]\nclass = success'),
#  Text(312.2582781456954, 67.30285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(313.7364238410596, 67.30285714285714, 'direct_assistance_awarded <= 102500.0\ngini = 0.443\nsamples = 22\nvalue = [2, 8, 24]\nclass = success'),
#  Text(311.1496688741722, 56.94857142857143, 'cont_jobs_total <= 12.5\ngini = 0.231\nsamples = 9\nvalue = [0, 2, 13]\nclass = success'),
#  Text(310.41059602649005, 46.59428571428572, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 7]\nclass = success'),
#  Text(311.88874172185433, 46.59428571428572, 'total_project_cost <= 7771029.0\ngini = 0.375\nsamples = 6\nvalue = [0, 2, 6]\nclass = success'),
#  Text(311.1496688741722, 36.24000000000001, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(312.62781456953644, 36.24000000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 6]\nclass = success'),
#  Text(316.32317880794704, 56.94857142857143, 'cont_jobs_total <= 27.5\ngini = 0.554\nsamples = 13\nvalue = [2, 6, 11]\nclass = success'),
#  Text(314.84503311258277, 46.59428571428572, 'direct_assistance_awarded <= 116500.0\ngini = 0.26\nsamples = 9\nvalue = [0, 2, 11]\nclass = success'),
#  Text(314.10596026490066, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(315.58410596026494, 36.24000000000001, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 11]\nclass = success'),
#  Text(317.80132450331126, 46.59428571428572, 'cont_jobs_total <= 29.5\ngini = 0.444\nsamples = 4\nvalue = [2, 4, 0]\nclass = pending'),
#  Text(317.06225165562915, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(318.5403973509934, 36.24000000000001, 'direct_assistance_awarded <= 165000.0\ngini = 0.48\nsamples = 3\nvalue = [2, 3, 0]\nclass = pending'),
#  Text(317.80132450331126, 25.8857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(319.2794701986755, 25.8857142857143, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(319.2794701986755, 88.01142857142858, 'company_funding <= 20827500.0\ngini = 0.129\nsamples = 26\nvalue = [1, 41, 2]\nclass = pending'),
#  Text(317.80132450331126, 77.65714285714284, 'cont_jobs_total <= 112.0\ngini = 0.071\nsamples = 17\nvalue = [1, 26, 0]\nclass = pending'),
#  Text(317.06225165562915, 67.30285714285714, 'gini = 0.0\nsamples = 14\nvalue = [0, 22, 0]\nclass = pending'),
#  Text(318.5403973509934, 67.30285714285714, 'cont_jobs_total <= 164.0\ngini = 0.32\nsamples = 3\nvalue = [1, 4, 0]\nclass = pending'),
#  Text(317.80132450331126, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(319.2794701986755, 56.94857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 4, 0]\nclass = pending'),
#  Text(320.75761589403976, 77.65714285714284, 'total_project_cost <= 30350000.0\ngini = 0.208\nsamples = 9\nvalue = [0, 15, 2]\nclass = pending'),
#  Text(320.01854304635765, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(321.49668874172187, 67.30285714285714, 'gini = 0.0\nsamples = 8\nvalue = [0, 15, 0]\nclass = pending'),
#  Text(326.6701986754967, 108.72, 'total_project_cost <= 5150000.0\ngini = 0.663\nsamples = 24\nvalue = [12, 15, 12]\nclass = pending'),
#  Text(325.9311258278146, 98.36571428571429, 'gini = 0.0\nsamples = 3\nvalue = [5, 0, 0]\nclass = failure'),
#  Text(327.4092715231788, 98.36571428571429, 'direct_assistance_awarded <= 606539.5\ngini = 0.638\nsamples = 21\nvalue = [7, 15, 12]\nclass = pending'),
#  Text(325.1920529801325, 88.01142857142858, 'company_funding <= 7795000.0\ngini = 0.567\nsamples = 8\nvalue = [3, 4, 10]\nclass = success'),
#  Text(324.45298013245036, 77.65714285714284, 'direct_assistance_awarded <= 550000.0\ngini = 0.408\nsamples = 7\nvalue = [0, 4, 10]\nclass = success'),
#  Text(322.9748344370861, 67.30285714285714, 'tax_benefits_awarded <= 117045.0\ngini = 0.49\nsamples = 4\nvalue = [0, 3, 4]\nclass = success'),
#  Text(322.235761589404, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(323.7139072847682, 56.94857142857143, 'company_funding <= 3701102.5\ngini = 0.48\nsamples = 3\nvalue = [0, 3, 2]\nclass = pending'),
#  Text(322.9748344370861, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 2]\nclass = success'),
#  Text(324.45298013245036, 46.59428571428572, 'gini = 0.0\nsamples = 2\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(325.9311258278146, 67.30285714285714, 'company_funding <= 4892500.0\ngini = 0.245\nsamples = 3\nvalue = [0, 1, 6]\nclass = success'),
#  Text(325.1920529801325, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pending'),
#  Text(326.6701986754967, 56.94857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 6]\nclass = success'),
#  Text(325.9311258278146, 77.65714285714284, 'gini = 0.0\nsamples = 1\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(329.6264900662252, 88.01142857142858, 'cont_jobs_total <= 148.0\ngini = 0.512\nsamples = 13\nvalue = [4, 11, 2]\nclass = pending'),
#  Text(328.1483443708609, 77.65714285714284, 'total_project_cost <= 213500000.0\ngini = 0.5\nsamples = 3\nvalue = [0, 2, 2]\nclass = pending'),
#  Text(327.4092715231788, 67.30285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 2, 0]\nclass = pending'),
#  Text(328.8874172185431, 67.30285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = success'),
#  Text(331.1046357615894, 77.65714285714284, 'total_project_cost <= 14649165.5\ngini = 0.426\nsamples = 10\nvalue = [4, 9, 0]\nclass = pending'),
#  Text(330.3655629139073, 67.30285714285714, 'gini = 0.0\nsamples = 4\nvalue = [0, 6, 0]\nclass = pending'),
#  Text(331.8437086092715, 67.30285714285714, 'tax_benefits_awarded <= 957426.5\ngini = 0.49\nsamples = 6\nvalue = [4, 3, 0]\nclass = failure'),
#  Text(331.1046357615894, 56.94857142857143, 'gini = 0.0\nsamples = 1\nvalue = [2, 0, 0]\nclass = failure'),
#  Text(332.5827814569536, 56.94857142857143, 'cont_jobs_total <= 177.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3, 0]\nclass = pending'),
#  Text(331.8437086092715, 46.59428571428572, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(333.3218543046358, 46.59428571428572, 'cont_jobs_total <= 285.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0]\nclass = pending'),
#  Text(332.5827814569536, 36.24000000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]\nclass = pending'),
#  Text(334.0609271523179, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(328.8874172185431, 119.07428571428571, 'company_funding <= 31568000.0\ngini = 0.219\nsamples = 3\nvalue = [1, 0, 7]\nclass = success'),
#  Text(328.1483443708609, 108.72, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = failure'),
#  Text(329.6264900662252, 108.72, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 7]\nclass = success'),
#  Text(269.74138038079474, 160.49142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 5]\nclass = success'),
#  Text(270.48045322847685, 170.84571428571428, 'gini = 0.0\nsamples = 22\nvalue = [0, 34, 0]\nclass = pending'),
#  Text(271.21952607615896, 181.2, 'gini = 0.0\nsamples = 18\nvalue = [0, 35, 0]\nclass = pending'),
#  Text(303.9956746688742, 191.5542857142857, 'total_project_cost <= 29763094.0\ngini = 0.48\nsamples = 14\nvalue = [10, 0, 15]\nclass = success'),
#  Text(303.2566018211921, 181.2, 'tax_benefits_awarded <= 128264.0\ngini = 0.5\nsamples = 12\nvalue = [10, 0, 10]\nclass = failure'),
#  Text(302.51752897350997, 170.84571428571428, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 8]\nclass = success'),
#  Text(303.9956746688742, 170.84571428571428, 'total_project_cost <= 10471683.5\ngini = 0.278\nsamples = 7\nvalue = [10, 0, 2]\nclass = failure'),
#  Text(303.2566018211921, 160.49142857142857, 'gini = 0.0\nsamples = 3\nvalue = [7, 0, 0]\nclass = failure'),
#  Text(304.7347475165563, 160.49142857142857, 'direct_assistance_awarded <= 300000.0\ngini = 0.48\nsamples = 4\nvalue = [3, 0, 2]\nclass = failure'),
#  Text(303.9956746688742, 150.13714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = success'),
#  Text(305.4738203642384, 150.13714285714286, 'gini = 0.0\nsamples = 2\nvalue = [3, 0, 0]\nclass = failure'),
#  Text(304.7347475165563, 181.2, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 5]\nclass = success')]

# %% [markdown]
# Overfitting on the train set.

# %% [markdown]
# Decent predictiveness on the test set.
